# %% [markdown]
# # 📊 Latest Working Version
#
# **This is the current working notebook for momentum strategy backtesting.**
#
# ---

# %% [markdown]
# # Monthly Momentum Strategy Backtest - 12-Month Return Formula
#
# This notebook implements a monthly momentum trading strategy using 12-month return formula.
#
# **Strategy Features:**
# - **12-Month Return Formula:** (Close_t-1 - Open_t-12) / Open_t-12
# - Uses previous month's closing price vs 12 months ago's opening price
# - Measures return over a 12-month period
# - Buy at close price on first trading day of current month
# - Sell at close price on last trading day of current month
# - Only positive momentum stocks (stocks that went up over 12 months)
# - Monthly rebalancing with profit reinvestment
# - Equal-weight allocation (₹5L per stock from ₹50L capital)

# %%
# Install required packages
# %pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\momentum_monthly_ro\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries
import pandas as pd
import numpy as np
from pathlib import Path
import logging
from typing import List, Dict, Tuple
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plotting
plt.style.use('dark_background')
sns.set_palette("husl")
# %matplotlib inline

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %% [markdown]
# ## 1. Data Loading

# %%
class DataLoader:
    """Handles loading and preprocessing of price data from CSV file."""
    
    def __init__(self, data_file: str = "data/combined_nifty50_6month_snapshots.csv"):
        self.data_file = Path(data_file)
        
    def load_price_data(self) -> pd.DataFrame:
        """Load OHLC price data from CSV file."""
        logger.info(f"Loading price data from {self.data_file}")
        
        if not self.data_file.exists():
            raise FileNotFoundError(f"Data file not found: {self.data_file}")
        
        # Load CSV file
        df = pd.read_csv(self.data_file)
        
        # Standardize column names to lowercase
        df = df.rename(columns={
            'DATE': 'date', 'SYMBOL': 'ticker', 'OPEN': 'open',
            'HIGH': 'high', 'LOW': 'low', 'CLOSE': 'close'
        })
        
        # Convert date to datetime
        df['date'] = pd.to_datetime(df['date'])
        
        # Sort by date and ticker
        df = df.sort_values(['date', 'ticker']).reset_index(drop=True)
        
        # Remove rows with invalid prices
        initial_rows = len(df)
        df = df[(df['open'] > 0) & (df['close'] > 0) & df['open'].notna() & df['close'].notna()]
        removed_rows = initial_rows - len(df)
        if removed_rows > 0:
            logger.warning(f"Removed {removed_rows} rows with invalid prices")
        
        logger.info(f"Loaded {len(df)} price records for {df['ticker'].nunique()} tickers "
                   f"from {df['date'].min()} to {df['date'].max()}")
        
        return df

# %% [markdown]
# ## 2. Monthly Price Computation

# %%
class MonthlyPriceComputer:
    """Computes monthly first-close and last-close prices from daily data."""
    
    @staticmethod
    def compute_monthly_prices(df: pd.DataFrame) -> pd.DataFrame:
        """Compute first trading day's close and last trading day's close for each month."""
        logger.info("Computing monthly first-close and last-close prices")
        
        # Add year-month column
        df = df.copy()
        df['year_month'] = df['date'].dt.to_period('M')
        
        # Group by ticker and year_month
        monthly = df.groupby(['ticker', 'year_month']).agg({
            'date': ['first', 'last'],
            'open': 'first',
            'close': ['first', 'last']
        }).reset_index()
        
        # Flatten column names
        monthly.columns = ['ticker', 'year_month', 'first_date', 'last_date', 'first_open', 'first_close', 'last_close']
        
        # Remove any rows with missing prices
        initial_rows = len(monthly)
        monthly = monthly.dropna(subset=['first_close', 'last_close'])
        removed_rows = initial_rows - len(monthly)
        if removed_rows > 0:
            logger.warning(f"Removed {removed_rows} month-ticker pairs with missing prices")
        
        # Convert Period back to timestamp for easier handling
        monthly['year_month_str'] = monthly['year_month'].astype(str)
        
        logger.info(f"Computed monthly prices for {len(monthly)} month-ticker pairs")
        
        return monthly

# %% [markdown]
# ## 3. Momentum Stock Selection

# %%
class MomentumSelector:
    """Selects top N stocks based on 12-month return (open t-12 to close t-1)."""
    
    def __init__(self, n_stocks: int = 10):
        """
        Initialize momentum selector.
        
        Args:
            n_stocks: Number of stocks to select each month
        
        Note: Uses 12-month return calculation
              - Formation period: 12 months (t-12 to t-1)
              - Return formula: (close_t-1 - open_t-12) / open_t-12
              - Uses previous month's closing price vs 12 months ago's opening price
              - Measures return over 12-month period
        """
        self.n_stocks = n_stocks
        
    def rank_and_select_tickers(
        self, 
        monthly_prices: pd.DataFrame, 
        current_month: pd.Period
    ) -> List[str]:
        """
        Select top N tickers based on 12-month return.
        
        Return Strategy:
        - Formation period: 12 months (t-12 to t-1)
        - Return Formula: (close_t-1 - open_t-12) / open_t-12
        - Uses previous month's closing price and 12 months ago's opening price
        """
        # Get the previous month (t-1) and 12 months ago (t-12)
        previous_month = current_month - 1
        start_month = current_month - 12
        
        # Get data for both periods
        prev_data = monthly_prices[monthly_prices['year_month'] == previous_month].copy()
        start_data = monthly_prices[monthly_prices['year_month'] == start_month].copy()
        
        if len(prev_data) == 0 or len(start_data) == 0:
            logger.warning(f"No data available for return calculation at {current_month}")
            return []
        
        # Merge on ticker to get both time periods
        # We need: CLOSE from previous month (t-1) and OPEN from 12 months ago (t-12)
        merged = prev_data[['ticker', 'last_close']].merge(
            start_data[['ticker', 'first_open']], 
            on='ticker', 
            suffixes=('_recent', '_start')
        )
        
        if len(merged) == 0:
            return []
        
        # Calculate 12-month return
        # Return = (Close_t-1 - Open_t-12) / Open_t-12
        merged['momentum_return'] = (merged['last_close'] - merged['first_open']) / merged['first_open']
        
        # Log the calculation for each stock
        for _, row in merged.iterrows():
            logger.info(f"{row['ticker']}: Open_t-12={row['first_open']:.2f}, Close_t-1={row['last_close']:.2f}, "
                       f"Return={(row['momentum_return']*100):.2f}%")
        
        # Filter out negative return stocks
        merged = merged[merged['momentum_return'] > 0]
        
        if len(merged) == 0:
            logger.warning(f"No stocks with positive return at {current_month}")
            return []
        
        # Rank by return and select top N
        merged = merged.sort_values('momentum_return', ascending=False)
        selected = merged.head(self.n_stocks)['ticker'].tolist()
        
        logger.info(f"Selected {len(selected)} stocks for {current_month} (Top Return: {merged['momentum_return'].iloc[0]*100:.2f}%)")
        
        return selected

# %% [markdown]
# ## 4. Capital Allocation

# %%
class CapitalAllocator:
    """Handles capital allocation across selected stocks."""
    
    @staticmethod
    def allocate_capital(
        capital: float,
        selected_tickers: List[str],
        monthly_prices: pd.DataFrame,
        current_month: pd.Period
    ) -> Tuple[Dict[str, Dict[str, float]], float]:
        """
        Allocate capital equally across selected tickers.
        Buys at the first trading day's close price.
        Only buys whole shares - remainder goes to base capital.
        
        Returns:
            Tuple of (allocations dict, unallocated cash)
        """
        if len(selected_tickers) == 0:
            return {}, capital
        
        # Get current month prices
        current_data = monthly_prices[
            (monthly_prices['year_month'] == current_month) & 
            (monthly_prices['ticker'].isin(selected_tickers))
        ]
        
        # Equal weight allocation - ₹5L per stock from ₹50L capital
        capital_per_stock = capital / len(selected_tickers)
        
        allocations = {}
        total_allocated = 0.0
        
        for ticker in selected_tickers:
            ticker_data = current_data[current_data['ticker'] == ticker]
            
            if len(ticker_data) == 0:
                logger.warning(f"No price data for {ticker} - skipping")
                continue
            
            buy_price = ticker_data['first_close'].iloc[0]  # Buy at month's first close
            shares = capital_per_stock / buy_price
            
            # Only buy whole shares - floor the shares
            shares = np.floor(shares)
            
            invested_amount = shares * buy_price
            
            allocations[ticker] = {
                'shares': shares,
                'buy_price': buy_price,
                'invested_amount': invested_amount
            }
            
            total_allocated += invested_amount
        
        unallocated = capital - total_allocated
        if abs(unallocated) > 0.01:
            logger.info(f"Uninvested cash (will be carried forward): ₹{unallocated:.2f}")
        
        return allocations, unallocated

# %% [markdown]
# ## 5. Monthly Simulator

# %%
class MonthlySimulator:
    """Simulates one month of trading - tracks entire month trajectory."""
    
    @staticmethod
    def simulate_month(
        allocations: Dict[str, Dict[str, float]],
        monthly_prices: pd.DataFrame,
        current_month: pd.Period,
        unallocated_cash: float = 0.0,
        transaction_cost_per_trade: float = 0.0,
        slippage: float = 0.0,
        tax_rate: float = 0.0
    ) -> Dict[str, float]:
        """
        Simulate one month of trading and compute returns.
        Buys at first day's close, holds through entire month, sells at last day's close.
        Uninvested cash is carried forward and added to ending capital for reinvestment.
        """
        current_data = monthly_prices[monthly_prices['year_month'] == current_month]
        
        total_start_value = sum(alloc['invested_amount'] for alloc in allocations.values())
        total_end_value = 0.0
        per_ticker_returns = {}
        total_costs = 0.0
        
        for ticker, alloc in allocations.items():
            ticker_data = current_data[current_data['ticker'] == ticker]
            
            if len(ticker_data) == 0:
                # If no data for the month, assume no change
                end_value = alloc['invested_amount']
            else:
                sell_price = ticker_data['last_close'].iloc[0]  # Sell at month's last close
                effective_sell_price = sell_price * (1 - slippage)
                end_value = alloc['shares'] * effective_sell_price
            
            # Calculate transaction costs
            if transaction_cost_per_trade < 1:
                trade_cost = alloc['invested_amount'] * transaction_cost_per_trade
            else:
                trade_cost = transaction_cost_per_trade
            
            total_costs += trade_cost * 2  # Buy and sell
            total_end_value += end_value
            
            ticker_return = (end_value - alloc['invested_amount']) / alloc['invested_amount']
            per_ticker_returns[ticker] = ticker_return
        
        gross_profit = total_end_value - total_start_value
        
        if gross_profit > 0:
            taxes = gross_profit * tax_rate
        else:
            taxes = 0.0
        
        net_profit = gross_profit - total_costs - taxes
        # Add uninvested cash to ending capital - this ensures it's reinvested next month
        ending_capital = total_start_value + net_profit + unallocated_cash
        
        return {
            'ending_capital': ending_capital,
            'gross_profit': gross_profit,
            'net_profit': net_profit,
            'total_costs': total_costs,
            'taxes': taxes,
            'unallocated_cash': unallocated_cash,
            'per_ticker_returns': per_ticker_returns
        }

# %% [markdown]
# ## 6. Backtest Engine

# %%
class BacktestEngine:
    """
    Main backtest orchestration engine.
    
    Strategy:
    - Starts from April 2017 (requires data from April 2016 for 12-month lookback)
    - Selects top 10 stocks using 12-month return: (Close_t-1 - Open_t-12) / Open_t-12
    - Allocates ₹50L capital equally (₹5L per stock)
    - Buys at close price on first trading day of month
    - Sells at close price on last trading day of month
    - Reinvests all profits into next month's capital
    - Continues until September 2025
    """
    
    def __init__(
        self,
        data_loader: DataLoader,
        selector: MomentumSelector,
        initial_capital: float = 5000000.0,
        transaction_cost_per_trade: float = 0.0,
        slippage: float = 0.0,
        tax_rate: float = 0.0
    ):
        self.data_loader = data_loader
        self.selector = selector
        self.initial_capital = initial_capital
        self.transaction_cost_per_trade = transaction_cost_per_trade
        self.slippage = slippage
        self.tax_rate = tax_rate
        
    def run_backtest(self) -> Tuple[pd.DataFrame, Dict]:
        """Run the complete backtest simulation."""
        logger.info("=" * 80)
        logger.info("Starting 12-Month Return Momentum Backtest")
        logger.info("Return Formula: (Close_t-1 - Open_t-12) / Open_t-12")
        logger.info(f"Initial Capital: ₹{self.initial_capital:,.2f}")
        logger.info("=" * 80)
        
        # Load and prepare data
        price_data = self.data_loader.load_price_data()
        monthly_prices = MonthlyPriceComputer.compute_monthly_prices(price_data)
        
        # Get list of all months
        all_months = sorted(monthly_prices['year_month'].unique())
        
        # Skip first 12 months for 12-month return lookback (need t-12 to t-1 data)
        # This means if we have data from 2016-04, we can start trading from 2017-04
        tradable_months = all_months[12:]
        
        logger.info(f"Backtest period: {tradable_months[0]} to {tradable_months[-1]} ({len(tradable_months)} months)")
        
        # Initialize tracking
        capital = self.initial_capital
        monthly_records = []
        
        # Run simulation for each month
        for month in tradable_months:
            logger.info("-" * 80)
            logger.info(f"Processing {month}")
            
            # Select stocks
            selected_tickers = self.selector.rank_and_select_tickers(monthly_prices, month)
            
            if len(selected_tickers) == 0:
                logger.warning(f"No stocks selected - skipping")
                continue
            
            # Allocate capital - now returns allocations AND unallocated cash
            allocations, unallocated_cash = CapitalAllocator.allocate_capital(
                capital=capital,
                selected_tickers=selected_tickers,
                monthly_prices=monthly_prices,
                current_month=month,
            )
            
            if len(allocations) == 0:
                continue
            
            # Simulate month - pass unallocated cash to be added to ending capital
            results = MonthlySimulator.simulate_month(
                allocations=allocations,
                monthly_prices=monthly_prices,
                current_month=month,
                unallocated_cash=unallocated_cash,
                transaction_cost_per_trade=self.transaction_cost_per_trade,
                slippage=self.slippage,
                tax_rate=self.tax_rate
            )
            
            portfolio_roi = results['net_profit'] / capital
            
            logger.info(f"Capital: ₹{capital:,.0f} → ₹{results['ending_capital']:,.0f} ({portfolio_roi*100:.2f}%)")
            
            # Record results
            monthly_records.append({
                'month': str(month),
                'capital_start': capital,
                'capital_end': results['ending_capital'],
                'net_profit': results['net_profit'],
                'gross_profit': results['gross_profit'],
                'total_costs': results['total_costs'],
                'taxes': results['taxes'],
                'unallocated_cash': results['unallocated_cash'],
                'portfolio_roi': portfolio_roi,
                'selected_tickers': ', '.join(selected_tickers),
                'num_stocks': len(allocations),
                'per_ticker_returns': str(results['per_ticker_returns'])
            })
            
            capital = results['ending_capital']
        
        ledger = pd.DataFrame(monthly_records)
        
        # Add cumulative returns using cumprod
        ledger['cumulative_return'] = (1 + ledger['portfolio_roi']).cumprod() - 1
        ledger['cumulative_return_pct'] = ledger['cumulative_return'] * 100
        
        metrics = self._compute_performance_metrics(ledger)
        
        logger.info("=" * 80)
        logger.info("Backtest Complete")
        logger.info("=" * 80)
        
        return ledger, metrics
    
    def _compute_performance_metrics(self, ledger: pd.DataFrame) -> Dict:
        """Compute aggregate performance metrics."""
        if len(ledger) == 0:
            return {}
        
        final_capital = ledger['capital_end'].iloc[-1]
        total_return = (final_capital - self.initial_capital) / self.initial_capital
        
        num_months = len(ledger)
        num_years = num_months / 12.0
        if num_years > 0:
            annualized_return = (1 + total_return) ** (1 / num_years) - 1
        else:
            annualized_return = None
        
        monthly_returns = ledger['portfolio_roi'].values
        avg_monthly_return = monthly_returns.mean()
        volatility = monthly_returns.std()
        
        if volatility > 0:
            sharpe_ratio = avg_monthly_return / volatility * np.sqrt(12)
        else:
            sharpe_ratio = None
        
        cumulative = (1 + ledger['portfolio_roi']).cumprod()
        running_max = cumulative.expanding().max()
        drawdown = (cumulative - running_max) / running_max
        max_drawdown = drawdown.min()
        
        win_rate = (monthly_returns > 0).sum() / len(monthly_returns)
        
        metrics = {
            'initial_capital': self.initial_capital,
            'final_capital': final_capital,
            'total_return': total_return,
            'total_return_pct': total_return * 100,
            'annualized_return': annualized_return,
            'annualized_return_pct': annualized_return * 100 if annualized_return else None,
            'avg_monthly_return': avg_monthly_return,
            'avg_monthly_return_pct': avg_monthly_return * 100,
            'monthly_volatility': volatility,
            'monthly_volatility_pct': volatility * 100,
            'sharpe_ratio': sharpe_ratio,
            'max_drawdown': max_drawdown,
            'max_drawdown_pct': max_drawdown * 100,
            'win_rate': win_rate,
            'win_rate_pct': win_rate * 100,
            'num_months': num_months,
            'num_years': num_years
        }
        
        logger.info("\nPerformance Summary:")
        logger.info(f"  Initial Capital: ₹{metrics['initial_capital']:,.2f}")
        logger.info(f"  Final Capital: ₹{metrics['final_capital']:,.2f}")
        logger.info(f"  Total Return: {metrics['total_return_pct']:.2f}%")
        if metrics['annualized_return_pct']:
            logger.info(f"  Annualized Return: {metrics['annualized_return_pct']:.2f}%")
        if metrics['sharpe_ratio']:
            logger.info(f"  Sharpe Ratio: {metrics['sharpe_ratio']:.2f}")
        logger.info(f"  Max Drawdown: {metrics['max_drawdown_pct']:.2f}%")
        logger.info(f"  Win Rate: {metrics['win_rate_pct']:.2f}%")
        
        return metrics

# %% [markdown]
# ## 🔧 STRATEGY UPDATE: 12-Month Momentum Formula
#
# **Formula:** (Close_t-1 - Open_t-12) / Open_t-12
#
# **What This Measures:**
# - Return over a 12-month period
# - Compares previous month's closing price to 12 months ago's opening price
# - Stocks that went up over 12 months will have positive returns
# - This is a classic long-term momentum indicator
#
# **Implementation:**
# 1. For current month t, we look at month t-12 (12 months ago) and month t-1 (previous month)
# 2. Calculate: (Close_t-1 - Open_t-12) / Open_t-12
# 3. Select top 10 stocks with highest positive returns
# 4. Log each stock's calculation for transparency
#
# **Example:** If a stock opened at ₹100 (12 months ago) and closed at ₹130 (last month), return = (130-100)/100 = 30%

# %%
# Configure backtest parameters
INITIAL_CAPITAL = 5_000_000  # 50 lakh INR
N_STOCKS = 10  # Top 10 stocks by ROI
ALLOW_FRACTIONAL_SHARES = False  # Allow fractional shares for exact ₹5L allocation
TRANSACTION_COST = 0.0  # No transaction costs
SLIPPAGE = 0.0  # No slippage
TAX_RATE = 0.0  # No taxes

# Initialize components
data_loader = DataLoader(data_file="data/combined_nifty50_6month_snapshots.csv")
selector = MomentumSelector(n_stocks=N_STOCKS)

# Create backtest engine
engine = BacktestEngine(
    data_loader=data_loader,
    selector=selector,
    initial_capital=INITIAL_CAPITAL,
    transaction_cost_per_trade=TRANSACTION_COST,
    slippage=SLIPPAGE,
    tax_rate=TAX_RATE
)

# Run backtest - will start from April 2017 and run until September 2025
# Each month: select top 10 stocks with highest 12-month return, invest equally, track for month, reinvest profits
ledger, metrics = engine.run_backtest()
# Out:
# 2025-10-08 13:07:12,858 - INFO - ================================================================================
# 2025-10-08 13:07:12,860 - INFO - Starting 12-Month Return Momentum Backtest
# 2025-10-08 13:07:12,861 - INFO - Return Formula: (Close_t-1 - Open_t-12) / Open_t-12
# 2025-10-08 13:07:12,862 - INFO - Initial Capital: ₹5,000,000.00
# 2025-10-08 13:07:12,862 - INFO - ================================================================================
# 2025-10-08 13:07:12,863 - INFO - Loading price data from data\combined_nifty50_6month_snapshots.csv
# 2025-10-08 13:07:13,398 - INFO - Loaded 109977 price records for 50 tickers from 2016-04-01 00:00:00 to 2025-09-26 00:00:00
# 2025-10-08 13:07:13,400 - INFO - Computing monthly first-close and last-close prices
# 2025-10-08 13:07:13,453 - INFO - Computed monthly prices for 5302 month-ticker pairs
# 2025-10-08 13:07:13,456 - INFO - Backtest period: 2017-04 to 2025-09 (102 months)
# 2025-10-08 13:07:13,458 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:13,459 - INFO - Processing 2017-04
# 2025-10-08 13:07:13,467 - INFO - ACC: Open_t-12=1371.25, Close_t-1=1446.05, Return=5.45%
# 2025-10-08 13:07:13,469 - INFO - ADANIPORTS: Open_t-12=248.00, Close_t-1=339.60, Return=36.94%
# 2025-10-08 13:07:13,470 - INFO - AMBUJACEM: Open_t-12=231.90, Close_t-1=236.65, Return=2.05%
# 2025-10-08 13:07:13,471 - INFO - ASIANPAINT: Open_t-12=871.00, Close_t-1=1073.50, Return=23.25%
# 2025-10-08 13:07:13,472 - INFO - AXISBANK: Open_t-12=440.90, Close_t-1=490.80, Return=11.32%
# 2025-10-08 13:07:13,473 - INFO - BAJAJ-AUTO: Open_t-12=2410.00, Close_t-1=2805.45, Return=16.41%
# 2025-10-08 13:07:13,474 - INFO - BANKBARODA: Open_t-12=145.70, Close_t-1=172.95, Return=18.70%
# 2025-10-08 13:07:13,476 - INFO - BHARTIARTL: Open_t-12=350.20, Close_t-1=350.05, Return=-0.04%
# 2025-10-08 13:07:13,477 - INFO - BHEL: Open_t-12=113.80, Close_t-1=162.85, Return=43.10%
# 2025-10-08 13:07:13,479 - INFO - BOSCHLTD: Open_t-12=20825.00, Close_t-1=22751.25, Return=9.25%
# 2025-10-08 13:07:13,480 - INFO - BPCL: Open_t-12=900.00, Close_t-1=649.85, Return=-27.79%
# 2025-10-08 13:07:13,481 - INFO - CAIRN: Open_t-12=154.50, Close_t-1=305.85, Return=97.96%
# 2025-10-08 13:07:13,482 - INFO - CIPLA: Open_t-12=513.80, Close_t-1=592.95, Return=15.40%
# 2025-10-08 13:07:13,483 - INFO - COALINDIA: Open_t-12=292.00, Close_t-1=292.65, Return=0.22%
# 2025-10-08 13:07:13,483 - INFO - GAIL: Open_t-12=354.65, Close_t-1=376.95, Return=6.29%
# 2025-10-08 13:07:13,485 - INFO - HCLTECH: Open_t-12=820.00, Close_t-1=874.75, Return=6.68%
# 2025-10-08 13:07:13,486 - INFO - HDFC: Open_t-12=1100.00, Close_t-1=1502.10, Return=36.55%
# 2025-10-08 13:07:13,487 - INFO - HEROMOTOCO: Open_t-12=2931.10, Close_t-1=3221.95, Return=9.92%
# 2025-10-08 13:07:13,488 - INFO - HINDALCO: Open_t-12=87.50, Close_t-1=195.05, Return=122.91%
# 2025-10-08 13:07:13,488 - INFO - HINDUNILVR: Open_t-12=867.10, Close_t-1=911.75, Return=5.15%
# 2025-10-08 13:07:13,489 - INFO - ICICIBANK: Open_t-12=236.00, Close_t-1=276.85, Return=17.31%
# 2025-10-08 13:07:13,489 - INFO - IDEA: Open_t-12=110.50, Close_t-1=85.85, Return=-22.31%
# 2025-10-08 13:07:13,490 - INFO - INDUSINDBK: Open_t-12=966.65, Close_t-1=1425.15, Return=47.43%
# 2025-10-08 13:07:13,491 - INFO - INFY: Open_t-12=1220.25, Close_t-1=1022.25, Return=-16.23%
# 2025-10-08 13:07:13,492 - INFO - ITC: Open_t-12=326.10, Close_t-1=280.30, Return=-14.04%
# 2025-10-08 13:07:13,493 - INFO - KOTAKBANK: Open_t-12=682.00, Close_t-1=872.20, Return=27.89%
# 2025-10-08 13:07:13,495 - INFO - LT: Open_t-12=1212.00, Close_t-1=1574.90, Return=29.94%
# 2025-10-08 13:07:13,497 - INFO - LUPIN: Open_t-12=1475.90, Close_t-1=1445.20, Return=-2.08%
# 2025-10-08 13:07:13,498 - INFO - M&M: Open_t-12=1206.70, Close_t-1=1286.90, Return=6.65%
# 2025-10-08 13:07:13,498 - INFO - MARUTI: Open_t-12=3700.45, Close_t-1=6015.70, Return=62.57%
# 2025-10-08 13:07:13,499 - INFO - NTPC: Open_t-12=128.70, Close_t-1=166.00, Return=28.98%
# 2025-10-08 13:07:13,500 - INFO - ONGC: Open_t-12=214.50, Close_t-1=185.00, Return=-13.75%
# 2025-10-08 13:07:13,500 - INFO - PNB: Open_t-12=84.50, Close_t-1=149.90, Return=77.40%
# 2025-10-08 13:07:13,503 - INFO - POWERGRID: Open_t-12=139.80, Close_t-1=197.30, Return=41.13%
# 2025-10-08 13:07:13,504 - INFO - RELIANCE: Open_t-12=1039.10, Close_t-1=1320.90, Return=27.12%
# 2025-10-08 13:07:13,505 - INFO - SBIN: Open_t-12=193.70, Close_t-1=293.40, Return=51.47%
# 2025-10-08 13:07:13,506 - INFO - SUNPHARMA: Open_t-12=821.00, Close_t-1=688.15, Return=-16.18%
# 2025-10-08 13:07:13,507 - INFO - TATAMOTORS: Open_t-12=386.40, Close_t-1=465.85, Return=20.56%
# 2025-10-08 13:07:13,509 - INFO - TATAPOWER: Open_t-12=64.95, Close_t-1=90.35, Return=39.11%
# 2025-10-08 13:07:13,511 - INFO - TCS: Open_t-12=2505.00, Close_t-1=2431.80, Return=-2.92%
# 2025-10-08 13:07:13,512 - INFO - TECHM: Open_t-12=476.00, Close_t-1=459.15, Return=-3.54%
# 2025-10-08 13:07:13,513 - INFO - ULTRACEMCO: Open_t-12=3249.00, Close_t-1=3984.75, Return=22.65%
# 2025-10-08 13:07:13,514 - INFO - VEDL: Open_t-12=89.75, Close_t-1=274.95, Return=206.35%
# 2025-10-08 13:07:13,516 - INFO - WIPRO: Open_t-12=567.00, Close_t-1=515.70, Return=-9.05%
# 2025-10-08 13:07:13,517 - INFO - ZEEL: Open_t-12=384.00, Close_t-1=535.55, Return=39.47%
# 2025-10-08 13:07:13,522 - INFO - Selected 10 stocks for 2017-04 (Top Return: 206.35%)
# 2025-10-08 13:07:13,532 - INFO - Uninvested cash (will be carried forward): ₹3756.85
# 2025-10-08 13:07:13,547 - INFO - Capital: ₹5,000,000 → ₹5,092,907 (1.86%)
# 2025-10-08 13:07:13,548 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:13,550 - INFO - Processing 2017-05
# 2025-10-08 13:07:13,562 - INFO - ACC: Open_t-12=1442.00, Close_t-1=1626.55, Return=12.80%
# 2025-10-08 13:07:13,567 - INFO - ADANIPORTS: Open_t-12=237.00, Close_t-1=327.70, Return=38.27%
# 2025-10-08 13:07:13,585 - INFO - AMBUJACEM: Open_t-12=221.05, Close_t-1=245.90, Return=11.24%
# 2025-10-08 13:07:13,592 - INFO - ASIANPAINT: Open_t-12=864.00, Close_t-1=1120.45, Return=29.68%
# 2025-10-08 13:07:13,594 - INFO - AXISBANK: Open_t-12=474.35, Close_t-1=509.65, Return=7.44%
# 2025-10-08 13:07:13,595 - INFO - BAJAJ-AUTO: Open_t-12=2484.00, Close_t-1=2864.00, Return=15.30%
# 2025-10-08 13:07:13,597 - INFO - BANKBARODA: Open_t-12=157.80, Close_t-1=187.55, Return=18.85%
# 2025-10-08 13:07:13,598 - INFO - BHARTIARTL: Open_t-12=363.00, Close_t-1=355.50, Return=-2.07%
# 2025-10-08 13:07:13,599 - INFO - BHEL: Open_t-12=125.00, Close_t-1=175.70, Return=40.56%
# 2025-10-08 13:07:13,600 - INFO - BOSCHLTD: Open_t-12=19660.00, Close_t-1=22991.60, Return=16.95%
# 2025-10-08 13:07:13,602 - INFO - BPCL: Open_t-12=982.00, Close_t-1=719.25, Return=-26.76%
# 2025-10-08 13:07:13,603 - INFO - CAIRN: Open_t-12=145.00, Close_t-1=285.35, Return=96.79%
# 2025-10-08 13:07:13,604 - INFO - CIPLA: Open_t-12=536.95, Close_t-1=557.45, Return=3.82%
# 2025-10-08 13:07:13,606 - INFO - COALINDIA: Open_t-12=288.70, Close_t-1=276.65, Return=-4.17%
# 2025-10-08 13:07:13,607 - INFO - GAIL: Open_t-12=360.00, Close_t-1=423.95, Return=17.76%
# 2025-10-08 13:07:13,608 - INFO - HCLTECH: Open_t-12=750.00, Close_t-1=814.10, Return=8.55%
# 2025-10-08 13:07:13,609 - INFO - HDFC: Open_t-12=1091.45, Close_t-1=1537.15, Return=40.84%
# 2025-10-08 13:07:13,611 - INFO - HEROMOTOCO: Open_t-12=2893.00, Close_t-1=3318.60, Return=14.71%
# 2025-10-08 13:07:13,613 - INFO - HINDALCO: Open_t-12=96.40, Close_t-1=199.35, Return=106.79%
# 2025-10-08 13:07:13,615 - INFO - HINDUNILVR: Open_t-12=867.00, Close_t-1=934.95, Return=7.84%
# 2025-10-08 13:07:13,616 - INFO - ICICIBANK: Open_t-12=227.30, Close_t-1=278.50, Return=22.53%
# 2025-10-08 13:07:13,618 - INFO - IDEA: Open_t-12=118.00, Close_t-1=85.95, Return=-27.16%
# 2025-10-08 13:07:13,619 - INFO - INDUSINDBK: Open_t-12=1043.00, Close_t-1=1444.95, Return=38.54%
# 2025-10-08 13:07:13,620 - INFO - INFY: Open_t-12=1210.00, Close_t-1=918.95, Return=-24.05%
# 2025-10-08 13:07:13,621 - INFO - ITC: Open_t-12=323.25, Close_t-1=278.00, Return=-14.00%
# 2025-10-08 13:07:13,622 - INFO - KOTAKBANK: Open_t-12=714.20, Close_t-1=901.95, Return=26.29%
# 2025-10-08 13:07:13,622 - INFO - LT: Open_t-12=1246.00, Close_t-1=1749.80, Return=40.43%
# 2025-10-08 13:07:13,624 - INFO - LUPIN: Open_t-12=1616.00, Close_t-1=1338.35, Return=-17.18%
# 2025-10-08 13:07:13,626 - INFO - M&M: Open_t-12=1319.00, Close_t-1=1335.55, Return=1.25%
# 2025-10-08 13:07:13,629 - INFO - MARUTI: Open_t-12=3799.90, Close_t-1=6524.85, Return=71.71%
# 2025-10-08 13:07:13,631 - INFO - NTPC: Open_t-12=139.30, Close_t-1=164.50, Return=18.09%
# 2025-10-08 13:07:13,632 - INFO - ONGC: Open_t-12=218.00, Close_t-1=186.55, Return=-14.43%
# 2025-10-08 13:07:13,633 - INFO - PNB: Open_t-12=86.80, Close_t-1=168.85, Return=94.53%
# 2025-10-08 13:07:13,635 - INFO - POWERGRID: Open_t-12=143.00, Close_t-1=208.00, Return=45.45%
# 2025-10-08 13:07:13,636 - INFO - RELIANCE: Open_t-12=979.00, Close_t-1=1395.20, Return=42.51%
# 2025-10-08 13:07:13,637 - INFO - SBIN: Open_t-12=187.60, Close_t-1=289.75, Return=54.45%
# 2025-10-08 13:07:13,638 - INFO - SUNPHARMA: Open_t-12=813.75, Close_t-1=641.95, Return=-21.11%
# 2025-10-08 13:07:13,640 - INFO - TATAMOTORS: Open_t-12=407.95, Close_t-1=458.90, Return=12.49%
# 2025-10-08 13:07:13,642 - INFO - TATAPOWER: Open_t-12=70.45, Close_t-1=84.30, Return=19.66%
# 2025-10-08 13:07:13,643 - INFO - TCS: Open_t-12=2529.00, Close_t-1=2273.15, Return=-10.12%
# 2025-10-08 13:07:13,645 - INFO - TECHM: Open_t-12=485.00, Close_t-1=416.95, Return=-14.03%
# 2025-10-08 13:07:13,646 - INFO - ULTRACEMCO: Open_t-12=3170.60, Close_t-1=4248.95, Return=34.01%
# 2025-10-08 13:07:13,647 - INFO - VEDL: Open_t-12=102.50, Close_t-1=243.55, Return=137.61%
# 2025-10-08 13:07:13,648 - INFO - WIPRO: Open_t-12=551.00, Close_t-1=494.25, Return=-10.30%
# 2025-10-08 13:07:13,649 - INFO - ZEEL: Open_t-12=414.00, Close_t-1=526.85, Return=27.26%
# 2025-10-08 13:07:13,652 - INFO - Selected 10 stocks for 2017-05 (Top Return: 137.61%)
# 2025-10-08 13:07:13,658 - WARNING - No price data for CAIRN - skipping
# 2025-10-08 13:07:13,665 - INFO - Uninvested cash (will be carried forward): ₹517792.25
# 2025-10-08 13:07:13,672 - INFO - Capital: ₹5,092,907 → ₹4,945,727 (-2.89%)
# 2025-10-08 13:07:13,672 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:13,673 - INFO - Processing 2017-06
# 2025-10-08 13:07:13,686 - INFO - ACC: Open_t-12=1535.00, Close_t-1=1637.05, Return=6.65%
# 2025-10-08 13:07:13,688 - INFO - ADANIPORTS: Open_t-12=192.85, Close_t-1=339.00, Return=75.78%
# 2025-10-08 13:07:13,691 - INFO - AMBUJACEM: Open_t-12=229.00, Close_t-1=241.25, Return=5.35%
# 2025-10-08 13:07:13,693 - INFO - ASIANPAINT: Open_t-12=989.05, Close_t-1=1151.20, Return=16.39%
# 2025-10-08 13:07:13,695 - INFO - AXISBANK: Open_t-12=524.85, Close_t-1=514.05, Return=-2.06%
# 2025-10-08 13:07:13,696 - INFO - BAJAJ-AUTO: Open_t-12=2635.00, Close_t-1=2845.95, Return=8.01%
# 2025-10-08 13:07:13,698 - INFO - BANKBARODA: Open_t-12=143.30, Close_t-1=178.05, Return=24.25%
# 2025-10-08 13:07:13,708 - INFO - BHARTIARTL: Open_t-12=353.55, Close_t-1=371.55, Return=5.09%
# 2025-10-08 13:07:13,714 - INFO - BHEL: Open_t-12=122.00, Close_t-1=138.20, Return=13.28%
# 2025-10-08 13:07:13,741 - INFO - BOSCHLTD: Open_t-12=22300.05, Close_t-1=23337.95, Return=4.65%
# 2025-10-08 13:07:13,749 - INFO - BPCL: Open_t-12=995.00, Close_t-1=742.65, Return=-25.36%
# 2025-10-08 13:07:13,750 - INFO - CIPLA: Open_t-12=474.70, Close_t-1=516.35, Return=8.77%
# 2025-10-08 13:07:13,752 - INFO - COALINDIA: Open_t-12=292.05, Close_t-1=262.55, Return=-10.10%
# 2025-10-08 13:07:13,754 - INFO - GAIL: Open_t-12=370.45, Close_t-1=414.00, Return=11.76%
# 2025-10-08 13:07:13,756 - INFO - HCLTECH: Open_t-12=744.00, Close_t-1=864.25, Return=16.16%
# 2025-10-08 13:07:13,757 - INFO - HDFC: Open_t-12=1242.15, Close_t-1=1569.85, Return=26.38%
# 2025-10-08 13:07:13,758 - INFO - HEROMOTOCO: Open_t-12=3123.70, Close_t-1=3745.45, Return=19.90%
# 2025-10-08 13:07:13,760 - INFO - HINDALCO: Open_t-12=105.35, Close_t-1=200.70, Return=90.51%
# 2025-10-08 13:07:13,761 - INFO - HINDUNILVR: Open_t-12=852.15, Close_t-1=1067.00, Return=25.21%
# 2025-10-08 13:07:13,763 - INFO - ICICIBANK: Open_t-12=243.90, Close_t-1=326.45, Return=33.85%
# 2025-10-08 13:07:13,766 - INFO - IDEA: Open_t-12=115.75, Close_t-1=80.00, Return=-30.89%
# 2025-10-08 13:07:13,768 - INFO - INDUSINDBK: Open_t-12=1103.00, Close_t-1=1480.70, Return=34.24%
# 2025-10-08 13:07:13,770 - INFO - INFY: Open_t-12=1246.05, Close_t-1=977.05, Return=-21.59%
# 2025-10-08 13:07:13,772 - INFO - ITC: Open_t-12=353.00, Close_t-1=311.80, Return=-11.67%
# 2025-10-08 13:07:13,774 - INFO - KOTAKBANK: Open_t-12=749.75, Close_t-1=966.05, Return=28.85%
# 2025-10-08 13:07:13,776 - INFO - LT: Open_t-12=1470.05, Close_t-1=1760.70, Return=19.77%
# 2025-10-08 13:07:13,778 - INFO - LUPIN: Open_t-12=1479.65, Close_t-1=1161.00, Return=-21.54%
# 2025-10-08 13:07:13,779 - INFO - M&M: Open_t-12=1329.00, Close_t-1=1416.95, Return=6.62%
# 2025-10-08 13:07:13,781 - INFO - MARUTI: Open_t-12=4170.70, Close_t-1=7211.00, Return=72.90%
# 2025-10-08 13:07:13,782 - INFO - NTPC: Open_t-12=142.90, Close_t-1=160.20, Return=12.11%
# 2025-10-08 13:07:13,782 - INFO - ONGC: Open_t-12=211.40, Close_t-1=177.00, Return=-16.27%
# 2025-10-08 13:07:13,786 - INFO - PNB: Open_t-12=79.00, Close_t-1=150.50, Return=90.51%
# 2025-10-08 13:07:13,790 - INFO - POWERGRID: Open_t-12=150.60, Close_t-1=207.95, Return=38.08%
# 2025-10-08 13:07:13,796 - INFO - RELIANCE: Open_t-12=957.95, Close_t-1=1340.70, Return=39.96%
# 2025-10-08 13:07:13,798 - INFO - SBIN: Open_t-12=205.95, Close_t-1=288.30, Return=39.99%
# 2025-10-08 13:07:13,800 - INFO - SUNPHARMA: Open_t-12=767.05, Close_t-1=501.60, Return=-34.61%
# 2025-10-08 13:07:13,804 - INFO - TATAMOTORS: Open_t-12=455.75, Close_t-1=476.15, Return=4.48%
# 2025-10-08 13:07:13,805 - INFO - TATAPOWER: Open_t-12=74.95, Close_t-1=81.00, Return=8.07%
# 2025-10-08 13:07:13,807 - INFO - TCS: Open_t-12=2571.20, Close_t-1=2546.60, Return=-0.96%
# 2025-10-08 13:07:13,810 - INFO - TECHM: Open_t-12=541.00, Close_t-1=390.00, Return=-27.91%
# 2025-10-08 13:07:13,811 - INFO - ULTRACEMCO: Open_t-12=3226.70, Close_t-1=4195.20, Return=30.02%
# 2025-10-08 13:07:13,812 - INFO - VEDL: Open_t-12=109.00, Close_t-1=238.65, Return=118.94%
# 2025-10-08 13:07:13,813 - INFO - WIPRO: Open_t-12=545.60, Close_t-1=535.50, Return=-1.85%
# 2025-10-08 13:07:13,815 - INFO - ZEEL: Open_t-12=445.70, Close_t-1=514.85, Return=15.51%
# 2025-10-08 13:07:13,820 - INFO - Selected 10 stocks for 2017-06 (Top Return: 118.94%)
# 2025-10-08 13:07:13,828 - INFO - Uninvested cash (will be carried forward): ₹4080.35
# 2025-10-08 13:07:13,838 - INFO - Capital: ₹4,945,727 → ₹4,898,916 (-0.95%)
# 2025-10-08 13:07:13,839 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:13,840 - INFO - Processing 2017-07
# 2025-10-08 13:07:13,847 - INFO - ACC: Open_t-12=1618.35, Close_t-1=1568.05, Return=-3.11%
# 2025-10-08 13:07:13,848 - INFO - ADANIPORTS: Open_t-12=205.10, Close_t-1=363.05, Return=77.01%
# 2025-10-08 13:07:13,849 - INFO - AMBUJACEM: Open_t-12=255.70, Close_t-1=246.55, Return=-3.58%
# 2025-10-08 13:07:13,851 - INFO - ASIANPAINT: Open_t-12=1002.80, Close_t-1=1102.95, Return=9.99%
# 2025-10-08 13:07:13,854 - INFO - AXISBANK: Open_t-12=535.80, Close_t-1=517.35, Return=-3.44%
# 2025-10-08 13:07:13,858 - INFO - BAJAJ-AUTO: Open_t-12=2697.50, Close_t-1=2791.20, Return=3.47%
# 2025-10-08 13:07:13,861 - INFO - BANKBARODA: Open_t-12=154.05, Close_t-1=161.65, Return=4.93%
# 2025-10-08 13:07:13,862 - INFO - BHARTIARTL: Open_t-12=365.80, Close_t-1=379.70, Return=3.80%
# 2025-10-08 13:07:13,862 - INFO - BHEL: Open_t-12=129.00, Close_t-1=135.30, Return=4.88%
# 2025-10-08 13:07:13,863 - INFO - BOSCHLTD: Open_t-12=22700.00, Close_t-1=23327.25, Return=2.76%
# 2025-10-08 13:07:13,864 - INFO - BPCL: Open_t-12=1075.00, Close_t-1=639.40, Return=-40.52%
# 2025-10-08 13:07:13,866 - INFO - CIPLA: Open_t-12=502.00, Close_t-1=555.60, Return=10.68%
# 2025-10-08 13:07:13,869 - INFO - COALINDIA: Open_t-12=313.00, Close_t-1=244.25, Return=-21.96%
# 2025-10-08 13:07:13,871 - INFO - GAIL: Open_t-12=388.00, Close_t-1=361.45, Return=-6.84%
# 2025-10-08 13:07:13,872 - INFO - HCLTECH: Open_t-12=735.00, Close_t-1=850.90, Return=15.77%
# 2025-10-08 13:07:13,874 - INFO - HDFC: Open_t-12=1253.50, Close_t-1=1614.95, Return=28.84%
# 2025-10-08 13:07:13,876 - INFO - HEROMOTOCO: Open_t-12=3188.70, Close_t-1=3701.35, Return=16.08%
# 2025-10-08 13:07:13,878 - INFO - HINDALCO: Open_t-12=124.00, Close_t-1=190.95, Return=53.99%
# 2025-10-08 13:07:13,880 - INFO - HINDUNILVR: Open_t-12=898.60, Close_t-1=1079.60, Return=20.14%
# 2025-10-08 13:07:13,881 - INFO - ICICIBANK: Open_t-12=241.70, Close_t-1=290.15, Return=20.05%
# 2025-10-08 13:07:13,882 - INFO - IDEA: Open_t-12=107.00, Close_t-1=85.25, Return=-20.33%
# 2025-10-08 13:07:13,884 - INFO - INDUSINDBK: Open_t-12=1125.00, Close_t-1=1478.95, Return=31.46%
# 2025-10-08 13:07:13,887 - INFO - INFY: Open_t-12=1180.00, Close_t-1=935.55, Return=-20.72%
# 2025-10-08 13:07:13,888 - INFO - ITC: Open_t-12=243.30, Close_t-1=323.65, Return=33.03%
# 2025-10-08 13:07:13,889 - INFO - KOTAKBANK: Open_t-12=764.00, Close_t-1=955.75, Return=25.10%
# 2025-10-08 13:07:13,890 - INFO - LT: Open_t-12=1504.80, Close_t-1=1687.60, Return=12.15%
# 2025-10-08 13:07:13,890 - INFO - LUPIN: Open_t-12=1545.00, Close_t-1=1059.85, Return=-31.40%
# 2025-10-08 13:07:13,893 - INFO - M&M: Open_t-12=1433.00, Close_t-1=1348.60, Return=-5.89%
# 2025-10-08 13:07:13,898 - INFO - MARUTI: Open_t-12=4188.60, Close_t-1=7217.60, Return=72.32%
# 2025-10-08 13:07:13,900 - INFO - NTPC: Open_t-12=155.30, Close_t-1=158.95, Return=2.35%
# 2025-10-08 13:07:13,901 - INFO - ONGC: Open_t-12=216.90, Close_t-1=157.30, Return=-27.48%
# 2025-10-08 13:07:13,903 - INFO - PNB: Open_t-12=106.10, Close_t-1=137.30, Return=29.41%
# 2025-10-08 13:07:13,905 - INFO - POWERGRID: Open_t-12=164.00, Close_t-1=210.55, Return=28.38%
# 2025-10-08 13:07:13,907 - INFO - RELIANCE: Open_t-12=972.75, Close_t-1=1380.00, Return=41.87%
# 2025-10-08 13:07:13,908 - INFO - SBIN: Open_t-12=220.80, Close_t-1=273.65, Return=23.94%
# 2025-10-08 13:07:13,910 - INFO - SUNPHARMA: Open_t-12=769.00, Close_t-1=555.70, Return=-27.74%
# 2025-10-08 13:07:13,912 - INFO - TATAMOTORS: Open_t-12=463.60, Close_t-1=432.55, Return=-6.70%
# 2025-10-08 13:07:13,913 - INFO - TATAPOWER: Open_t-12=74.00, Close_t-1=80.55, Return=8.85%
# 2025-10-08 13:07:13,914 - INFO - TCS: Open_t-12=2562.00, Close_t-1=2362.35, Return=-7.79%
# 2025-10-08 13:07:13,915 - INFO - TECHM: Open_t-12=508.20, Close_t-1=382.00, Return=-24.83%
# 2025-10-08 13:07:13,916 - INFO - ULTRACEMCO: Open_t-12=3410.00, Close_t-1=3959.10, Return=16.10%
# 2025-10-08 13:07:13,917 - INFO - VEDL: Open_t-12=132.95, Close_t-1=249.05, Return=87.33%
# 2025-10-08 13:07:13,918 - INFO - WIPRO: Open_t-12=559.75, Close_t-1=258.35, Return=-53.85%
# 2025-10-08 13:07:13,919 - INFO - ZEEL: Open_t-12=459.50, Close_t-1=491.35, Return=6.93%
# 2025-10-08 13:07:13,922 - INFO - Selected 10 stocks for 2017-07 (Top Return: 87.33%)
# 2025-10-08 13:07:13,933 - INFO - Uninvested cash (will be carried forward): ₹7071.05
# 2025-10-08 13:07:13,942 - INFO - Capital: ₹4,898,916 → ₹5,279,638 (7.77%)
# 2025-10-08 13:07:13,942 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07
- INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:14,026 - INFO - Processing 2017-09
# 2025-10-08 13:07:14,033 - INFO - ACC: Open_t-12=1668.00, Close_t-1=1800.25, Return=7.93%
# 2025-10-08 13:07:14,034 - INFO - ADANIPORTS: Open_t-12=263.15, Close_t-1=392.95, Return=49.33%
# 2025-10-08 13:07:14,035 - INFO - AMBUJACEM: Open_t-12=273.70, Close_t-1=280.35, Return=2.43%
# 2025-10-08 13:07:14,036 - INFO - ASIANPAINT: Open_t-12=1159.85, Close_t-1=1168.55, Return=0.75%
# 2025-10-08 13:07:14,037 - INFO - AXISBANK: Open_t-12=597.05, Close_t-1=500.35, Return=-16.20%
# 2025-10-08 13:07:14,038 - INFO - BAJAJ-AUTO: Open_t-12=2978.50, Close_t-1=2814.50, Return=-5.51%
# 2025-10-08 13:07:14,039 - INFO - BANKBARODA: Open_t-12=163.50, Close_t-1=137.85, Return=-15.69%
# 2025-10-08 13:07:14,041 - INFO - BHARTIARTL: Open_t-12=330.00, Close_t-1=427.70, Return=29.61%
# 2025-10-08 13:07:14,043 - INFO - BHEL: Open_t-12=139.10, Close_t-1=128.90, Return=-7.33%
# 2025-10-08 13:07:14,044 - INFO - BOSCHLTD: Open_t-12=24280.00, Close_t-1=21986.80, Return=-9.44%
# 2025-10-08 13:07:14,045 - INFO - BPCL: Open_t-12=600.30, Close_t-1=529.00, Return=-11.88%
# 2025-10-08 13:07:14,046 - INFO - CIPLA: Open_t-12=575.00, Close_t-1=571.90, Return=-0.54%
# 2025-10-08 13:07:14,047 - INFO - COALINDIA: Open_t-12=334.10, Close_t-1=237.40, Return=-28.94%
# 2025-10-08 13:07:14,048 - INFO - GAIL: Open_t-12=383.00, Close_t-1=378.30, Return=-1.23%
# 2025-10-08 13:07:14,049 - INFO - HCLTECH: Open_t-12=781.30, Close_t-1=865.30, Return=10.75%
# 2025-10-08 13:07:14,050 - INFO - HDFC: Open_t-12=1412.00, Close_t-1=1776.90, Return=25.84%
# 2025-10-08 13:07:14,051 - INFO - HEROMOTOCO: Open_t-12=3560.00, Close_t-1=3995.10, Return=12.22%
# 2025-10-08 13:07:14,052 - INFO - HINDALCO: Open_t-12=159.00, Close_t-1=238.00, Return=49.69%
# 2025-10-08 13:07:14,053 - INFO - HINDUNILVR: Open_t-12=917.10, Close_t-1=1219.75, Return=33.00%
# 2025-10-08 13:07:14,054 - INFO - ICICIBANK: Open_t-12=258.75, Close_t-1=298.05, Return=15.19%
# 2025-10-08 13:07:14,055 - INFO - IDEA: Open_t-12=93.10, Close_t-1=90.65, Return=-2.63%
# 2025-10-08 13:07:14,056 - INFO - INDUSINDBK: Open_t-12=1191.75, Close_t-1=1656.75, Return=39.02%
# 2025-10-08 13:07:14,058 - INFO - INFY: Open_t-12=1038.00, Close_t-1=914.95, Return=-11.85%
# 2025-10-08 13:07:14,059 - INFO - ITC: Open_t-12=261.00, Close_t-1=282.25, Return=8.14%
# 2025-10-08 13:07:14,060 - INFO - KOTAKBANK: Open_t-12=813.00, Close_t-1=976.00, Return=20.05%
# 2025-10-08 13:07:14,061 - INFO - LT: Open_t-12=1513.00, Close_t-1=1136.30, Return=-24.90%
# 2025-10-08 13:07:14,062 - INFO - LUPIN: Open_t-12=1482.20, Close_t-1=979.45, Return=-33.92%
# 2025-10-08 13:07:14,063 - INFO - M&M: Open_t-12=1439.00, Close_t-1=1344.80, Return=-6.55%
# 2025-10-08 13:07:14,064 - INFO - MARUTI: Open_t-12=5074.00, Close_t-1=7700.30, Return=51.76%
# 2025-10-08 13:07:14,065 - INFO - NTPC: Open_t-12=159.70, Close_t-1=168.75, Return=5.67%
# 2025-10-08 13:07:14,065 - INFO - ONGC: Open_t-12=237.00, Close_t-1=156.95, Return=-33.78%
# 2025-10-08 13:07:14,066 - INFO - PNB: Open_t-12=127.25, Close_t-1=143.80, Return=13.01%
# 2025-10-08 13:07:14,066 - INFO - POWERGRID: Open_t-12=183.50, Close_t-1=219.25, Return=19.48%
# 2025-10-08 13:07:14,067 - INFO - RELIANCE: Open_t-12=1053.00, Close_t-1=1594.50, Return=51.42%
# 2025-10-08 13:07:14,068 - INFO - SBIN: Open_t-12=251.95, Close_t-1=277.75, Return=10.24%
# 2025-10-08 13:07:14,070 - INFO - SUNPHARMA: Open_t-12=775.60, Close_t-1=481.15, Return=-37.96%
# 2025-10-08 13:07:14,071 - INFO - TATAMOTORS: Open_t-12=540.50, Close_t-1=376.55, Return=-30.33%
# 2025-10-08 13:07:14,073 - INFO - TATAPOWER: Open_t-12=79.80, Close_t-1=79.25, Return=-0.69%
# 2025-10-08 13:07:14,076 - INFO - TCS: Open_t-12=2524.90, Close_t-1=2496.35, Return=-1.13%
# 2025-10-08 13:07:14,077 - INFO - TECHM: Open_t-12=470.00, Close_t-1=428.15, Return=-8.90%
# 2025-10-08 13:07:14,079 - INFO - ULTRACEMCO: Open_t-12=3960.00, Close_t-1=4000.40, Return=1.02%
# 2025-10-08 13:07:14,079 - INFO - VEDL: Open_t-12=169.35, Close_t-1=308.90, Return=82.40%
# 2025-10-08 13:07:14,080 - INFO - WIPRO: Open_t-12=489.70, Close_t-1=299.10, Return=-38.92%
# 2025-10-08 13:07:14,081 - INFO - ZEEL: Open_t-12=544.85, Close_t-1=519.50, Return=-4.65%
# 2025-10-08 13:07:14,083 - INFO - Selected 10 stocks for 2017-09 (Top Return: 82.40%)
# 2025-10-08 13:07:14,091 - INFO - Uninvested cash (will be carried forward): ₹10246.10
# 2025-10-08 13:07:14,101 - INFO - Capital: ₹5,207,439 → ₹4,856,752 (-6.73%)
# 2025-10-08 13:07:14,103 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:14,104 - INFO - Processing 2017-10
# 2025-10-08 13:07:14,113 - INFO - ACC: Open_t-12=1615.00, Close_t-1=1656.90, Return=2.59%
# 2025-10-08 13:07:14,115 - INFO - ADANIPORTS: Open_t-12=260.70, Close_t-1=376.75, Return=44.51%
# 2025-10-08 13:07:14,117 - INFO - AMBUJACEM: Open_t-12=253.40, Close_t-1=266.45, Return=5.15%
# 2025-10-08 13:07:14,121 - INFO - ASIANPAINT: Open_t-12=1170.00, Close_t-1=1131.70, Return=-3.27%
# 2025-10-08 13:07:14,122 - INFO - AXISBANK: Open_t-12=542.95, Close_t-1=509.15, Return=-6.23%
# 2025-10-08 13:07:14,123 - INFO - BAJAJ-AUTO: Open_t-12=2830.00, Close_t-1=3109.40, Return=9.87%
# 2025-10-08 13:07:14,125 - INFO - BANKBARODA: Open_t-12=168.10, Close_t-1=137.60, Return=-18.14%
# 2025-10-08 13:07:14,126 - INFO - BHARTIARTL: Open_t-12=314.00, Close_t-1=389.45, Return=24.03%
# 2025-10-08 13:07:14,128 - INFO - BHEL: Open_t-12=136.60, Close_t-1=83.95, Return=-38.54%
# 2025-10-08 13:07:14,129 - INFO - BOSCHLTD: Open_t-12=22930.00, Close_t-1=20545.10, Return=-10.40%
# 2025-10-08 13:07:14,130 - INFO - BPCL: Open_t-12=616.00, Close_t-1=471.30, Return=-23.49%
# 2025-10-08 13:07:14,132 - INFO - CIPLA: Open_t-12=584.70, Close_t-1=586.10, Return=0.24%
# 2025-10-08 13:07:14,132 - INFO - COALINDIA: Open_t-12=323.10, Close_t-1=270.85, Return=-16.17%
# 2025-10-08 13:07:14,133 - INFO - GAIL: Open_t-12=372.95, Close_t-1=419.05, Return=12.36%
# 2025-10-08 13:07:14,133 - INFO - GRASIM: Open_t-12=1015.00, Close_t-1=1133.95, Return=11.72%
# 2025-10-08 13:07:14,134 - INFO - HCLTECH: Open_t-12=805.00, Close_t-1=874.80, Return=8.67%
# 2025-10-08 13:07:14,136 - INFO - HDFC: Open_t-12=1401.00, Close_t-1=1742.15, Return=24.35%
# 2025-10-08 13:07:14,137 - INFO - HEROMOTOCO: Open_t-12=3436.40, Close_t-1=3774.55, Return=9.84%
# 2025-10-08 13:07:14,138 - INFO - HINDALCO: Open_t-12=154.50, Close_t-1=240.60, Return=55.73%
# 2025-10-08 13:07:14,140 - INFO - HINDUNILVR: Open_t-12=878.00, Close_t-1=1173.90, Return=33.70%
# 2025-10-08 13:07:14,141 - INFO - ICICIBANK: Open_t-12=251.00, Close_t-1=276.60, Return=10.20%
# 2025-10-08 13:07:14,143 - INFO - IDEA: Open_t-12=80.10, Close_t-1=77.45, Return=-3.31%
# 2025-10-08 13:07:14,145 - INFO - INDUSINDBK: Open_t-12=1201.00, Close_t-1=1682.20, Return=40.07%
# 2025-10-08 13:07:14,146 - INFO - INFY: Open_t-12=1035.50, Close_t-1=899.90, Return=-13.10%
# 2025-10-08 13:07:14,148 - INFO - ITC: Open_t-12=244.20, Close_t-1=258.30, Return=5.77%
# 2025-10-08 13:07:14,148 - INFO - KOTAKBANK: Open_t-12=788.95, Close_t-1=1002.25, Return=27.04%
# 2025-10-08 13:07:14,149 - INFO - LT: Open_t-12=1438.05, Close_t-1=1142.05, Return=-20.58%
# 2025-10-08 13:07:14,150 - INFO - LUPIN: Open_t-12=1486.25, Close_t-1=1014.00, Return=-31.77%
# 2025-10-08 13:07:14,152 - INFO - M&M: Open_t-12=1413.00, Close_t-1=1254.25, Return=-11.23%
# 2025-10-08 13:07:14,154 - INFO - MARUTI: Open_t-12=5661.00, Close_t-1=7978.20, Return=40.93%
# 2025-10-08 13:07:14,154 - INFO - NTPC: Open_t-12=148.75, Close_t-1=167.45, Return=12.57%
# 2025-10-08 13:07:14,155 - INFO - ONGC: Open_t-12=257.00, Close_t-1=170.95, Return=-33.48%
# 2025-10-08 13:07:14,156 - INFO - PNB: Open_t-12=143.20, Close_t-1=129.05, Return=-9.88%
# 2025-10-08 13:07:14,158 - INFO - POWERGRID: Open_t-12=177.15, Close_t-1=211.00, Return=19.11%
# 2025-10-08 13:07:14,159 - INFO - RELIANCE: Open_t-12=1087.00, Close_t-1=780.90, Return=-28.16%
# 2025-10-08 13:07:14,161 - INFO - SBIN: Open_t-12=253.00, Close_t-1=253.85, Return=0.34%
# 2025-10-08 13:07:14,164 - INFO - SUNPHARMA: Open_t-12=750.00, Close_t-1=503.25, Return=-32.90%
# 2025-10-08 13:07:14,166 - INFO - TATAMOTORS: Open_t-12=539.40, Close_t-1=401.50, Return=-25.57%
# 2025-10-08 13:07:14,167 - INFO - TATAPOWER: Open_t-12=75.50, Close_t-1=77.80, Return=3.05%
# 2025-10-08 13:07:14,169 - INFO - TCS: Open_t-12=2450.00, Close_t-1=2435.95, Return=-0.57%
# 2025-10-08 13:07:14,171 - INFO - TECHM: Open_t-12=420.00, Close_t-1=457.85, Return=9.01%
# 2025-10-08 13:07:14,172 - INFO - ULTRACEMCO: Open_t-12=3874.90, Close_t-1=3854.20, Return=-0.53%
# 2025-10-08 13:07:14,173 - INFO - VEDL: Open_t-12=173.85, Close_t-1=314.25, Return=80.76%
# 2025-10-08 13:07:14,174 - INFO - WIPRO: Open_t-12=480.00, Close_t-1=280.25, Return=-41.61%
# 2025-10-08 13:07:14,177 - INFO - ZEEL: Open_t-12=552.40, Close_t-1=520.10, Return=-5.85%
# 2025-10-08 13:07:14,181 - INFO - Selected 10 stocks for 2017-10 (Top Return: 80.76%)
# 2025-10-08 13:07:14,189 - INFO - Uninvested cash (will be carried forward): ₹9009.80
# 2025-10-08 13:07:14,200 - INFO - Capital: ₹4,856,752 → ₹5,159,630 (6.24%)
# 2025-10-08 13:07:14,200 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:14,201 - INFO - Processing 2017-11
# 2025-10-08 13:07:14,208 - INFO - ACC: Open_t-12=1514.70, Close_t-1=1809.50, Return=19.46%
# 2025-10-08 13:07:14,210 - INFO - ADANIPORTS: Open_t-12=307.00, Close_t-1=430.35, Return=40.18%
# 2025-10-08 13:07:14,212 - INFO - AMBUJACEM: Open_t-12=239.70, Close_t-1=281.50, Return=17.44%
# 2025-10-08 13:07:14,213 - INFO - ASIANPAINT: Open_t-12=1077.10, Close_t-1=1180.85, Return=9.63%
# 2025-10-08 13:07:14,214 - INFO - AXISBANK: Open_t-12=488.05, Close_t-1=523.15, Return=7.19%
# 2025-10-08 13:07:14,215 - INFO - BAJAJ-AUTO: Open_t-12=2830.40, Close_t-1=3257.10, Return=15.08%
# 2025-10-08 13:07:14,216 - INFO - BANKBARODA: Open_t-12=156.60, Close_t-1=169.90, Return=8.49%
# 2025-10-08 13:07:14,217 - INFO - BHARTIARTL: Open_t-12=318.00, Close_t-1=497.20, Return=56.35%
# 2025-10-08 13:07:14,217 - INFO - BHEL: Open_t-12=140.00, Close_t-1=98.00, Return=-30.00%
# 2025-10-08 13:07:14,219 - INFO - BOSCHLTD: Open_t-12=21900.00, Close_t-1=21012.20, Return=-4.05%
# 2025-10-08 13:07:14,220 - INFO - BPCL: Open_t-12=671.05, Close_t-1=541.60, Return=-19.29%
# 2025-10-08 13:07:14,220 - INFO - CIPLA: Open_t-12=579.45, Close_t-1=627.60, Return=8.31%
# 2025-10-08 13:07:14,221 - INFO - COALINDIA: Open_t-12=326.50, Close_t-1=286.45, Return=-12.27%
# 2025-10-08 13:07:14,221 - INFO - GAIL: Open_t-12=432.80, Close_t-1=465.20, Return=7.49%
# 2025-10-08 13:07:14,225 - INFO - GRASIM: Open_t-12=976.90, Close_t-1=1227.10, Return=25.61%
# 2025-10-08 13:07:14,227 - INFO - HCLTECH: Open_t-12=771.80, Close_t-1=855.80, Return=10.88%
# 2025-10-08 13:07:14,228 - INFO - HDFC: Open_t-12=1382.60, Close_t-1=1707.40, Return=23.49%
# 2025-10-08 13:07:14,230 - INFO - HEROMOTOCO: Open_t-12=3380.00, Close_t-1=3849.90, Return=13.90%
# 2025-10-08 13:07:14,230 - INFO - HINDALCO: Open_t-12=150.50, Close_t-1=267.40, Return=77.67%
# 2025-10-08 13:07:14,232 - INFO - HINDUNILVR: Open_t-12=835.00, Close_t-1=1237.45, Return=48.20%
# 2025-10-08 13:07:14,233 - INFO - ICICIBANK: Open_t-12=279.45, Close_t-1=300.10, Return=7.39%
# 2025-10-08 13:07:14,234 - INFO - IDEA: Open_t-12=76.80, Close_t-1=92.85, Return=20.90%
# 2025-10-08 13:07:14,235 - INFO - INDUSINDBK: Open_t-12=1197.00, Close_t-1=1627.15, Return=35.94%
# 2025-10-08 13:07:14,236 - INFO - INFY: Open_t-12=1006.80, Close_t-1=921.85, Return=-8.44%
# 2025-10-08 13:07:14,237 - INFO - ITC: Open_t-12=242.80, Close_t-1=265.70, Return=9.43%
# 2025-10-08 13:07:14,238 - INFO - KOTAKBANK: Open_t-12=819.90, Close_t-1=1025.05, Return=25.02%
# 2025-10-08 13:07:14,239 - INFO - LT: Open_t-12=1481.00, Close_t-1=1222.30, Return=-17.47%
# 2025-10-08 13:07:14,240 - INFO - LUPIN: Open_t-12=1532.00, Close_t-1=1028.05, Return=-32.89%
# 2025-10-08 13:07:14,240 - INFO - M&M: Open_t-12=1320.90, Close_t-1=1344.80, Return=1.81%
# 2025-10-08 13:07:14,241 - INFO - MARUTI: Open_t-12=5919.00, Close_t-1=8211.25, Return=38.73%
# 2025-10-08 13:07:14,242 - INFO - NTPC: Open_t-12=151.70, Close_t-1=181.25, Return=19.48%
# 2025-10-08 13:07:14,243 - INFO - ONGC: Open_t-12=290.30, Close_t-1=191.10, Return=-34.17%
# 2025-10-08 13:07:14,244 - INFO - PNB: Open_t-12=144.70, Close_t-1=197.15, Return=36.25%
# 2025-10-08 13:07:14,246 - INFO - POWERGRID: Open_t-12=175.25, Close_t-1=211.85, Return=20.88%
# 2025-10-08 13:07:14,307 - INFO - CIPLA: Open_t-12=567.00, Close_t-1=600.90, Return=5.98%
# 2025-10-08 13:07:14,308 - INFO - COALINDIA: Open_t-12=309.20, Close_t-1=275.80, Return=-10.80%
# 2025-10-08 13:07:14,309 - INFO - GAIL: Open_t-12=426.00, Close_t-1=468.40, Return=9.95%
# 2025-10-08 13:07:14,310 - INFO - GRASIM: Open_t-12=875.00, Close_t-1=1169.90, Return=33.70%
# 2025-10-08 13:07:14,312 - INFO - HCLTECH: Open_t-12=803.90, Close_t-1=848.00, Return=5.49%
# 2025-10-08 13:07:14,313 - INFO - HDFC: Open_t-12=1268.40, Close_t-1=1675.70, Return=32.11%
# 2025-10-08 13:07:14,314 - INFO - HEROMOTOCO: Open_t-12=3161.00, Close_t-1=3633.65, Return=14.95%
# 2025-10-08 13:07:14,315 - INFO - HINDALCO: Open_t-12=176.80, Close_t-1=240.45, Return=36.00%
# 2025-10-08 13:07:14,316 - INFO - HINDUNILVR: Open_t-12=844.00, Close_t-1=1272.45, Return=50.76%
# 2025-10-08 13:07:14,316 - INFO - ICICIBANK: Open_t-12=266.25, Close_t-1=307.55, Return=15.51%
# 2025-10-08 13:07:14,317 - INFO - IDEA: Open_t-12=77.10, Close_t-1=94.45, Return=22.50%
# 2025-10-08 13:07:14,317 - INFO - INDUSINDBK: Open_t-12=1084.00, Close_t-1=1661.95, Return=53.32%
# 2025-10-08 13:07:14,318 - INFO - INFY: Open_t-12=976.00, Close_t-1=976.10, Return=0.01%
# 2025-10-08 13:07:14,320 - INFO - ITC: Open_t-12=232.80, Close_t-1=256.05, Return=9.99%
# 2025-10-08 13:07:14,321 - INFO - KOTAKBANK: Open_t-12=755.00, Close_t-1=1000.30, Return=32.49%
# 2025-10-08 13:07:14,322 - INFO - LT: Open_t-12=1386.40, Close_t-1=1216.55, Return=-12.25%
# 2025-10-08 13:07:14,324 - INFO - LUPIN: Open_t-12=1505.00, Close_t-1=817.70, Return=-45.67%
# 2025-10-08 13:07:14,326 - INFO - M&M: Open_t-12=1190.00, Close_t-1=1406.55, Return=18.20%
# 2025-10-08 13:07:14,328 - INFO - MARUTI: Open_t-12=5266.00, Close_t-1=8599.10, Return=63.29%
# 2025-10-08 13:07:14,329 - INFO - NTPC: Open_t-12=163.15, Close_t-1=181.15, Return=11.03%
# 2025-10-08 13:07:14,330 - INFO - ONGC: Open_t-12=295.00, Close_t-1=180.65, Return=-38.76%
# 2025-10-08 13:07:14,331 - INFO - PNB: Open_t-12=138.95, Close_t-1=176.10, Return=26.74%
# 2025-10-08 13:07:14,331 - INFO - POWERGRID: Open_t-12=192.50, Close_t-1=206.05, Return=7.04%
# 2025-10-08 13:07:14,332 - INFO - RELIANCE: Open_t-12=1000.00, Close_t-1=921.55, Return=-7.85%
# 2025-10-08 13:07:14,333 - INFO - SBIN: Open_t-12=259.65, Close_t-1=320.35, Return=23.38%
# 2025-10-08 13:07:14,333 - INFO - SUNPHARMA: Open_t-12=709.80, Close_t-1=539.95, Return=-23.93%
# 2025-10-08 13:07:14,334 - INFO - TATAMOTORS: Open_t-12=457.00, Close_t-1=404.15, Return=-11.56%
# 2025-10-08 13:07:14,337 - INFO - TATAPOWER: Open_t-12=74.80, Close_t-1=94.70, Return=26.60%
# 2025-10-08 13:07:14,339 - INFO - TCS: Open_t-12=2277.00, Close_t-1=2637.00, Return=15.81%
# 2025-10-08 13:07:14,341 - INFO - TECHM: Open_t-12=480.05, Close_t-1=489.25, Return=1.92%
# 2025-10-08 13:07:14,342 - INFO - ULTRACEMCO: Open_t-12=3619.70, Close_t-1=4203.80, Return=16.14%
# 2025-10-08 13:07:14,344 - INFO - VEDL: Open_t-12=233.05, Close_t-1=295.45, Return=26.78%
# 2025-10-08 13:07:14,345 - INFO - WIPRO: Open_t-12=469.70, Close_t-1=291.90, Return=-37.85%
# 2025-10-08 13:07:14,347 - INFO - ZEEL: Open_t-12=456.90, Close_t-1=568.15, Return=24.35%
# 2025-10-08 13:07:14,349 - INFO - Selected 10 stocks for 2017-12 (Top Return: 63.29%)
# 2025-10-08 13:07:14,357 - INFO - Uninvested cash (will be carried forward): ₹8787.15
# 2025-10-08 13:07:14,366 - INFO - Capital: ₹4,870,928 → ₹5,221,746 (7.20%)
# 2025-10-08 13:07:14,366 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:14,367 - INFO - Processing 2018-01
# 2025-10-08 13:07:14,375 - INFO - ACC: Open_t-12=1340.00, Close_t-1=1758.40, Return=31.22%
# 2025-10-08 13:07:14,377 - INFO - ADANIPORTS: Open_t-12=269.80, Close_t-1=405.65, Return=50.35%
# 2025-10-08 13:07:14,378 - INFO - AMBUJACEM: Open_t-12=209.00, Close_t-1=272.05, Return=30.17%
# 2025-10-08 13:07:14,379 - INFO - ASIANPAINT: Open_t-12=893.00, Close_t-1=1158.50, Return=29.73%
# 2025-10-08 13:07:14,380 - INFO - AXISBANK: Open_t-12=451.40, Close_t-1=563.95, Return=24.93%
# 2025-10-08 13:07:14,381 - INFO - BAJAJ-AUTO: Open_t-12=2642.70, Close_t-1=3333.60, Return=26.14%
# 2025-10-08 13:07:14,382 - INFO - BANKBARODA: Open_t-12=153.95, Close_t-1=160.65, Return=4.35%
# 2025-10-08 13:07:14,382 - INFO - BHARTIARTL: Open_t-12=303.10, Close_t-1=529.65, Return=74.74%
# 2025-10-08 13:07:14,383 - INFO - BHEL: Open_t-12=121.20, Close_t-1=92.50, Return=-23.68%
# 2025-10-08 13:07:14,383 - INFO - BOSCHLTD: Open_t-12=21200.00, Close_t-1=20165.55, Return=-4.88%
# 2025-10-08 13:07:14,384 - INFO - BPCL: Open_t-12=640.00, Close_t-1=517.70, Return=-19.11%
# 2025-10-08 13:07:14,387 - INFO - CIPLA: Open_t-12=569.75, Close_t-1=608.50, Return=6.80%
# 2025-10-08 13:07:14,388 - INFO - COALINDIA: Open_t-12=300.05, Close_t-1=262.95, Return=-12.36%
# 2025-10-08 13:07:14,389 - INFO - GAIL: Open_t-12=440.00, Close_t-1=499.65, Return=13.56%
# 2025-10-08 13:07:22,723 - INFO - ULTRACEMCO: Open_t-12=10300.00, Close_t-1=11210.00, Return=8.83%
# 2025-10-08 13:07:22,725 - INFO - VEDL: Open_t-12=472.00, Close_t-1=435.55, Return=-7.72%
# 2025-10-08 13:07:22,727 - INFO - WIPRO: Open_t-12=450.20, Close_t-1=249.67, Return=-44.54%
# 2025-10-08 13:07:22,728 - INFO - YESBANK: Open_t-12=24.40, Close_t-1=21.48, Return=-11.97%
# 2025-10-08 13:07:22,730 - INFO - ZEEL: Open_t-12=160.00, Close_t-1=130.42, Return=-18.49%
# 2025-10-08 13:07:22,733 - INFO - Selected 10 stocks for 2025-06 (Top Return: 31.15%)
# 2025-10-08 13:07:22,741 - INFO - Uninvested cash (will be carried forward): ₹14129.19
# 2025-10-08 13:07:22,750 - INFO - Capital: ₹8,357,249 → ₹8,719,476 (4.33%)
# 2025-10-08 13:07:22,751 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:22,751 - INFO - Processing 2025-07
# 2025-10-08 13:07:22,758 - INFO - ACC: Open_t-12=2634.75, Close_t-1=1917.20, Return=-27.23%
# 2025-10-08 13:07:22,760 - INFO - ADANIPORTS: Open_t-12=1483.00, Close_t-1=1450.20, Return=-2.21%
# 2025-10-08 13:07:22,761 - INFO - AMBUJACEM: Open_t-12=668.00, Close_t-1=577.45, Return=-13.56%
# 2025-10-08 13:07:22,762 - INFO - ASIANPAINT: Open_t-12=2889.30, Close_t-1=2341.10, Return=-18.97%
# 2025-10-08 13:07:22,764 - INFO - AXISBANK: Open_t-12=1273.00, Close_t-1=1199.20, Return=-5.80%
# 2025-10-08 13:07:22,765 - INFO - BAJAJ-AUTO: Open_t-12=9505.00, Close_t-1=8376.00, Return=-11.88%
# 2025-10-08 13:07:22,766 - INFO - BANKBARODA: Open_t-12=275.25, Close_t-1=248.78, Return=-9.62%
# 2025-10-08 13:07:22,766 - INFO - BHARTIARTL: Open_t-12=1450.00, Close_t-1=2009.60, Return=38.59%
# 2025-10-08 13:07:22,767 - INFO - BHEL: Open_t-12=301.95, Close_t-1=266.30, Return=-11.81%
# 2025-10-08 13:07:22,768 - INFO - BOSCHLTD: Open_t-12=34000.05, Close_t-1=32680.00, Return=-3.88%
# 2025-10-08 13:07:22,768 - INFO - BPCL: Open_t-12=305.70, Close_t-1=331.95, Return=8.59%
# 2025-10-08 13:07:22,769 - INFO - CIPLA: Open_t-12=1484.95, Close_t-1=1505.90, Return=1.41%
# 2025-10-08 13:07:22,769 - INFO - COALINDIA: Open_t-12=473.35, Close_t-1=391.95, Return=-17.20%
# 2025-10-08 13:07:22,770 - INFO - GAIL: Open_t-12=220.25, Close_t-1=190.84, Return=-13.35%
# 2025-10-08 13:07:22,772 - INFO - GRASIM: Open_t-12=2666.20, Close_t-1=2844.50, Return=6.69%
# 2025-10-08 13:07:22,773 - INFO - HCLTECH: Open_t-12=1465.00, Close_t-1=1728.60, Return=17.99%
# 2025-10-08 13:07:22,773 - INFO - HDFCBANK: Open_t-12=1680.00, Close_t-1=2001.50, Return=19.14%
# 2025-10-08 13:07:22,776 - INFO - HEROMOTOCO: Open_t-12=5595.00, Close_t-1=4237.10, Return=-24.27%
# 2025-10-08 13:07:22,777 - INFO - HINDALCO: Open_t-12=699.00, Close_t-1=692.85, Return=-0.88%
# 2025-10-08 13:07:22,779 - INFO - HINDUNILVR: Open_t-12=2461.05, Close_t-1=2294.60, Return=-6.76%
# 2025-10-08 13:07:22,780 - INFO - ICICIBANK: Open_t-12=1199.60, Close_t-1=1445.80, Return=20.52%
# 2025-10-08 13:07:22,781 - INFO - IDEA: Open_t-12=17.79, Close_t-1=7.43, Return=-58.23%
# 2025-10-08 13:07:22,783 - INFO - INDUSINDBK: Open_t-12=1468.95, Close_t-1=872.10, Return=-40.63%
# 2025-10-08 13:07:22,784 - INFO - INFY: Open_t-12=1559.50, Close_t-1=1601.80, Return=2.71%
# 2025-10-08 13:07:22,784 - INFO - ITC: Open_t-12=426.30, Close_t-1=416.45, Return=-2.31%
# 2025-10-08 13:07:22,785 - INFO - KOTAKBANK: Open_t-12=1802.50, Close_t-1=2163.50, Return=20.03%
# 2025-10-08 13:07:22,786 - INFO - LT: Open_t-12=3535.20, Close_t-1=3669.80, Return=3.81%
# 2025-10-08 13:07:22,786 - INFO - LUPIN: Open_t-12=1615.05, Close_t-1=1938.00, Return=20.00%
# 2025-10-08 13:07:22,789 - INFO - M&M: Open_t-12=2841.00, Close_t-1=3183.20, Return=12.05%
# 2025-10-08 13:07:22,791 - INFO - MARUTI: Open_t-12=12045.00, Close_t-1=12400.00, Return=2.95%
# 2025-10-08 13:07:22,793 - INFO - NTPC: Open_t-12=381.75, Close_t-1=334.90, Return=-12.27%
# 2025-10-08 13:07:22,795 - INFO - ONGC: Open_t-12=275.00, Close_t-1=244.21, Return=-11.20%
# 2025-10-08 13:07:22,796 - INFO - PNB: Open_t-12=123.15, Close_t-1=110.50, Return=-10.27%
# 2025-10-08 13:07:22,797 - INFO - POWERGRID: Open_t-12=331.00, Close_t-1=299.90, Return=-9.40%
# 2025-10-08 13:07:22,798 - INFO - RELIANCE: Open_t-12=3125.05, Close_t-1=1500.60, Return=-51.98%
# 2025-10-08 13:07:22,799 - INFO - SBIN: Open_t-12=849.35, Close_t-1=820.35, Return=-3.41%
# 2025-10-08 13:07:22,801 - INFO - SUNPHARMA: Open_t-12=1520.85, Close_t-1=1675.70, Return=10.18%
# 2025-10-08 13:07:22,802 - INFO - TATAMOTORS: Open_t-12=989.75, Close_t-1=688.00, Return=-30.49%
# 2025-10-08 13:07:22,802 - INFO - TATAPOWER: Open_t-12=441.00, Close_t-1=405.45, Return=-8.06%
# 2025-10-08 13:07:22,803 - INFO - TATASTEEL: Open_t-12=174.50, Close_t-1=159.76, Return=-8.45%
# 2025-10-08 13:07:22,803 - INFO - TCS: Open_t-12=3884.00, Close_t-1=3462.00, Return=-10.87%
# 2025-10-08 13:07:22,807 - INFO - TECHM: Open_t-12=1430.35, Close_t-1=1687.00, Return=17.94%
# 2025-10-08 13:07:22,869 - INFO - HEROMOTOCO: Open_t-12=5487.45, Close_t-1=4260.70, Return=-22.36%
# 2025-10-08 13:07:22,869 - INFO - HINDALCO: Open_t-12=680.00, Close_t-1=683.05, Return=0.45%
# 2025-10-08 13:07:22,870 - INFO - HINDUNILVR: Open_t-12=2714.00, Close_t-1=2521.20, Return=-7.10%
# 2025-10-08 13:07:22,877 - INFO - ICICIBANK: Open_t-12=1212.50, Close_t-1=1481.40, Return=22.18%
# 2025-10-08 13:07:22,879 - INFO - IDEA: Open_t-12=16.36, Close_t-1=6.91, Return=-57.76%
# 2025-10-08 13:07:22,881 - INFO - INDUSINDBK: Open_t-12=1432.00, Close_t-1=798.90, Return=-44.21%
# 2025-10-08 13:07:22,882 - INFO - INFY: Open_t-12=1856.10, Close_t-1=1509.00, Return=-18.70%
# 2025-10-08 13:07:22,883 - INFO - ITC: Open_t-12=495.95, Close_t-1=411.95, Return=-16.94%
# 2025-10-08 13:07:22,885 - INFO - KOTAKBANK: Open_t-12=1807.10, Close_t-1=1978.60, Return=9.49%
# 2025-10-08 13:07:22,885 - INFO - LT: Open_t-12=3810.00, Close_t-1=3636.50, Return=-4.55%
# 2025-10-08 13:07:22,886 - INFO - LUPIN: Open_t-12=1911.00, Close_t-1=1929.10, Return=0.95%
# 2025-10-08 13:07:22,886 - INFO - M&M: Open_t-12=2926.50, Close_t-1=3203.10, Return=9.45%
# 2025-10-08 13:07:22,887 - INFO - MARUTI: Open_t-12=13393.00, Close_t-1=12608.00, Return=-5.86%
# 2025-10-08 13:07:22,889 - INFO - NTPC: Open_t-12=419.90, Close_t-1=334.25, Return=-20.40%
# 2025-10-08 13:07:22,890 - INFO - ONGC: Open_t-12=337.80, Close_t-1=241.00, Return=-28.66%
# 2025-10-08 13:07:22,891 - INFO - PNB: Open_t-12=124.50, Close_t-1=105.38, Return=-15.36%
# 2025-10-08 13:07:22,892 - INFO - POWERGRID: Open_t-12=351.15, Close_t-1=291.00, Return=-17.13%
# 2025-10-08 13:07:22,894 - INFO - RELIANCE: Open_t-12=3024.00, Close_t-1=1390.20, Return=-54.03%
# 2025-10-08 13:07:22,895 - INFO - SBIN: Open_t-12=877.80, Close_t-1=796.55, Return=-9.26%
# 2025-10-08 13:07:22,896 - INFO - SUNPHARMA: Open_t-12=1725.50, Close_t-1=1706.70, Return=-1.09%
# 2025-10-08 13:07:22,897 - INFO - TATAMOTORS: Open_t-12=1167.00, Close_t-1=665.95, Return=-42.93%
# 2025-10-08 13:07:22,898 - INFO - TATAPOWER: Open_t-12=454.95, Close_t-1=397.75, Return=-12.57%
# 2025-10-08 13:07:22,899 - INFO - TATASTEEL: Open_t-12=168.20, Close_t-1=157.94, Return=-6.10%
# 2025-10-08 13:07:22,899 - INFO - TCS: Open_t-12=4399.40, Close_t-1=3036.80, Return=-30.97%
# 2025-10-08 13:07:22,900 - INFO - TECHM: Open_t-12=1554.40, Close_t-1=1463.70, Return=-5.84%
# 2025-10-08 13:07:22,901 - INFO - ULTRACEMCO: Open_t-12=11887.20, Close_t-1=12249.00, Return=3.04%
# 2025-10-08 13:07:22,963 - INFO - HINDALCO: Open_t-12=706.70, Close_t-1=703.95, Return=-0.39%
# 2025-10-08 13:07:22,965 - INFO - HINDUNILVR: Open_t-12=2794.00, Close_t-1=2659.80, Return=-4.80%
# 2025-10-08 13:07:22,966 - INFO - ICICIBANK: Open_t-12=1239.00, Close_t-1=1397.80, Return=12.82%
# 2025-10-08 13:07:22,968 - INFO - IDEA: Open_t-12=15.58, Close_t-1=6.49, Return=-58.34%
# 2025-10-08 13:07:22,968 - INFO - INDUSINDBK: Open_t-12=1425.25, Close_t-1=739.50, Return=-48.11%
# 2025-10-08 13:07:22,969 - INFO - INFY: Open_t-12=1943.35, Close_t-1=1469.60, Return=-24.38%
# 2025-10-08 13:07:22,969 - INFO - ITC: Open_t-12=504.00, Close_t-1=409.75, Return=-18.70%
# 2025-10-08 13:07:22,970 - INFO - KOTAKBANK: Open_t-12=1782.00, Close_t-1=1960.30, Return=10.01%
# 2025-10-08 13:07:22,973 - INFO - LT: Open_t-12=3706.00, Close_t-1=3601.00, Return=-2.83%
# 2025-10-08 13:07:22,976 - INFO - LUPIN: Open_t-12=2257.00, Close_t-1=1894.90, Return=-16.04%
# 2025-10-08 13:07:22,978 - INFO - M&M: Open_t-12=2848.80, Close_t-1=3199.50, Return=12.31%
# 2025-10-08 13:07:22,979 - INFO - MARUTI: Open_t-12=12373.00, Close_t-1=14791.00, Return=19.54%
# 2025-10-08 13:07:22,981 - INFO - NTPC: Open_t-12=417.80, Close_t-1=327.55, Return=-21.60%
# 2025-10-08 13:07:22,982 - INFO - ONGC: Open_t-12=330.00, Close_t-1=233.71, Return=-29.18%
# 2025-10-08 13:07:22,983 - INFO - PNB: Open_t-12=116.94, Close_t-1=100.88, Return=-13.73%
# 2025-10-08 13:07:22,984 - INFO - POWERGRID: Open_t-12=338.40, Close_t-1=275.25, Return=-18.66%
# 2025-10-08 13:07:22,984 - INFO - RELIANCE: Open_t-12=3021.75, Close_t-1=1357.20, Return=-55.09%
# 2025-10-08 13:07:22,985 - INFO - SBIN: Open_t-12=817.30, Close_t-1=802.50, Return=-1.81%
# 2025-10-08 13:07:22,985 - INFO - SUNPHARMA: Open_t-12=1829.95, Close_t-1=1594.50, Return=-12.87%
# 2025-10-08 13:07:22,986 - INFO - TATAMOTORS: Open_t-12=1105.00, Close_t-1=669.00, Return=-39.46%
# 2025-10-08 13:07:22,986 - INFO - TATAPOWER: Open_t-12=435.85, Close_t-1=374.15, Return=-14.16%
# 2025-10-08 13:07:22,987 - INFO - TATASTEEL: Open_t-12=153.90, Close_t-1=154.48, Return=0.38%
# 2025-10-08 13:07:22,989 - INFO - TCS: Open_t-12=4576.00, Close_t-1=3084.70, Return=-32.59%
# 2025-10-08 13:07:22,990 - INFO - TECHM: Open_t-12=1636.50, Close_t-1=1481.40, Return=-9.48%
# 2025-10-08 13:07:22,992 - INFO - ULTRACEMCO: Open_t-12=11325.00, Close_t-1=12640.00, Return=11.61%
# 2025-10-08 13:07:22,993 - INFO - VEDL: Open_t-12=472.70, Close_t-1=420.65, Return=-11.01%
# 2025-10-08 13:07:22,994 - INFO - WIPRO: Open_t-12=538.40, Close_t-1=249.41, Return=-53.68%
# 2025-10-08 13:07:22,995 - INFO - YESBANK: Open_t-12=23.61, Close_t-1=19.10, Return=-19.10%
# 2025-10-08 13:07:22,997 - INFO - ZEEL: Open_t-12=141.38, Close_t-1=116.04, Return=-17.92%
# 2025-10-08 13:07:23,000 - INFO - Selected 9 stocks for 2025-09 (Top Return: 23.37%)
# 2025-10-08 13:07:23,012 - INFO - Uninvested cash (will be carried forward): ₹51469.31
# 2025-10-08 13:07:23,020 - INFO - Capital: ₹8,039,268 → ₹8,074,257 (0.44%)
# 2025-10-08 13:07:23,025 - INFO -
# Performance Summary:
# 2025-10-08 13:07:23,027 - INFO -   Initial Capital: ₹5,000,000.00
# 2025-10-08 13:07:23,027 - INFO -   Final Capital: ₹8,074,257.01
# 2025-10-08 13:07:23,028 - INFO -   Total Return: 61.49%
# 2025-10-08 13:07:23,029 - INFO -   Annualized Return: 5.80%
# 2025-10-08 13:07:23,030 - INFO -   Sharpe Ratio: 0.41
# 2025-10-08 13:07:23,030 - INFO -   Max Drawdown: -27.13%
# 2025-10-08 13:07:23,031 - INFO -   Win Rate: 51.96%
# 2025-10-08 13:07:23,031 - INFO - ================================================================================
# 2025-10-08 13:07:23,032 - INFO - Backtest Complete
# 2025-10-08 13:07:23,032 - INFO - ================================================================================

# %%
# Run the backtest with 12-month momentum formula
print("=" * 80)
print("RUNNING 12-MONTH MOMENTUM BACKTEST")
print("Formula: (Close_t-1 - Open_t-12) / Open_t-12")
print("=" * 80)
print()

ledger, metrics = engine.run_backtest()

print("\n" + "=" * 80)
print("BACKTEST RESULTS (12-Month Momentum Strategy)")
print("=" * 80)
# Out:
# 2025-10-08 13:07:23,043 - INFO - ================================================================================
# 2025-10-08 13:07:23,043 - INFO - Starting 12-Month Return Momentum Backtest
# 2025-10-08 13:07:23,044 - INFO - Return Formula: (Close_t-1 - Open_t-12) / Open_t-12
# 2025-10-08 13:07:23,045 - INFO - Initial Capital: ₹5,000,000.00
# 2025-10-08 13:07:23,045 - INFO - ================================================================================
# 2025-10-08 13:07:23,045 - INFO - Loading price data from data\combined_nifty50_6month_snapshots.csv
# ================================================================================
# RUNNING 12-MONTH MOMENTUM BACKTEST
# Formula: (Close_t-1 - Open_t-12) / Open_t-12
# ================================================================================
# 2025-10-08 13:07:23,512 - INFO - Loaded 109977 price records for 50 tickers from 2016-04-01 00:00:00 to 2025-09-26 00:00:00
# 2025-10-08 13:07:23,514 - INFO - Computing monthly first-close and last-close prices
# 2025-10-08 13:07:23,590 - INFO - Computed monthly prices for 5302 month-ticker pairs
# 2025-10-08 13:07:23,595 - INFO - Backtest period: 2017-04 to 2025-09 (102 months)
# 2025-10-08 13:07:23,597 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:23,598 - INFO - Processing 2017-04
# 2025-10-08 13:07:23,603 - INFO - ACC: Open_t-12=1371.25, Close_t-1=1446.05, Return=5.45%
# 2025-10-08 13:07:23,609 - INFO - ADANIPORTS: Open_t-12=248.00, Close_t-1=339.60, Return=36.94%
# 2025-10-08 13:07:23,613 - INFO - AMBUJACEM: Open_t-12=231.90, Close_t-1=236.65, Return=2.05%
# 2025-10-08 13:07:23,618 - INFO - ASIANPAINT: Open_t-12=871.00, Close_t-1=1073.50, Return=23.25%
# 2025-10-08 13:07:23,620 - INFO - AXISBANK: Open_t-12=440.90, Close_t-1=490.80, Return=11.32%
# 2025-10-08 13:07:23,630 - INFO - BAJAJ-AUTO: Open_t-12=2410.00, Close_t-1=2805.45, Return=16.41%
# 2025-10-08 13:07:23,633 - INFO - BANKBARODA: Open_t-12=145.70, Close_t-1=172.95, Return=18.70%
# 2025-10-08 13:07:23,635 - INFO - BHARTIARTL: Open_t-12=350.20, Close_t-1=350.05, Return=-0.04%
# 2025-10-08 13:07:23,636 - INFO - BHEL: Open_t-12=113.80, Close_t-1=162.85, Return=43.10%
# 2025-10-08 13:07:23,637 - INFO - BOSCHLTD: Open_t-12=20825.00, Close_t-1=22751.25, Return=9.25%
# 2025-10-08 13:07:23,642 - INFO - BPCL: Open_t-12=900.00, Close_t-1=649.85, Return=-27.79%
# 2025-10-08 13:07:23,644 - INFO - CAIRN: Open_t-12=154.50, Close_t-1=305.85, Return=97.96%
# 2025-10-08 13:07:23,647 - INFO - CIPLA: Open_t-12=513.80, Close_t-1=592.95, Return=15.40%
# 2025-10-08 13:07:23,648 - INFO - COALINDIA: Open_t-12=292.00, Close_t-1=292.65, Return=0.22%
# 2025-10-08 13:07:23,650 - INFO - GAIL: Open_t-12=354.65, Close_t-1=376.95, Return=6.29%
# 2025-10-08 13:07:23,651 - INFO - HCLTECH: Open_t-12=820.00, Close_t-1=874.75, Return=6.68%
# 2025-10-08 13:07:23,651 - INFO - HDFC: Open_t-12=1100.00, Close_t-1=1502.10, Return=36.55%
# 2025-10-08 13:07:23,652 - INFO - HEROMOTOCO: Open_t-12=2931.10, Close_t-1=3221.95, Return=9.92%
# 2025-10-08 13:07:23,653 - INFO - HINDALCO: Open_t-12=87.50, Close_t-1=195.05, Return=122.91%
# 2025-10-08 13:07:23,653 - INFO - HINDUNILVR: Open_t-12=867.10, Close_t-1=911.75, Return=5.15%
# 2025-10-08 13:07:23,654 - INFO - ICICIBANK: Open_t-12=236.00, Close_t-1=276.85, Return=17.31%
# 2025-10-08 13:07:23,657 - INFO - IDEA: Open_t-12=110.50, Close_t-1=85.85, Return=-22.31%
# 2025-10-08 13:07:23,659 - INFO - INDUSINDBK: Open_t-12=966.65, Close_t-1=1425.15, Return=47.43%
# 2025-10-08 13:07:23,661 - INFO - INFY: Open_t-12=1220.25, Close_t-1=1022.25, Return=-16.23%
# 2025-10-08 13:07:23,663 - INFO - ITC: Open_t-12=326.10, Close_t-1=280.30, Return=-14.04%
# 2025-10-08 13:07:23,664 - INFO - KOTAKBANK: Open_t-12=682.00, Close_t-1=872.20, Return=27.89%
# 2025-10-08 13:07:23,665 - INFO - LT: Open_t-12=1212.00, Close_t-1=1574.90, Return=29.94%
# 2025-10-08 13:07:23,666 - INFO - LUPIN: Open_t-12=1475.90, Close_t-1=1445.20, Return=-2.08%
# 2025-10-08 13:07:23,667 - INFO - M&M: Open_t-12=1206.70, Close_t-1=1286.90, Return=6.65%
# 2025-10-08 13:07:23,668 - INFO - MARUTI: Open_t-12=3700.45, Close_t-1=6015.70, Return=62.57%
# 2025-10-08 13:07:23,669 - INFO - NTPC: Open_t-12=128.70, Close_t-1=166.00, Return=28.98%
# 2025-10-08 13:07:23,670 - INFO - ONGC: Open_t-12=214.50, Close_t-1=185.00, Return=-13.75%
# 2025-10-08 13:07:23,670 - INFO - PNB: Open_t-12=84.50, Close_t-1=149.90, Return=77.40%
# 2025-10-08 13:07:23,673 - INFO - POWERGRID: Open_t-12=139.80, Close_t-1=197.30, Return=41.13%
# 2025-10-08 13:07:23,674 - INFO - RELIANCE: Open_t-12=1039.10, Close_t-1=1320.90, Return=27.12%
# 2025-10-08 13:07:23,676 - INFO - SBIN: Open_t-12=193.70, Close_t-1=293.40, Return=51.47%
# 2025-10-08 13:07:23,678 - INFO - SUNPHARMA: Open_t-12=821.00, Close_t-1=688.15, Return=-16.18%
# 2025-10-08 13:07:23,680 - INFO - TATAMOTORS: Open_t-12=386.40, Close_t-1=465.85, Return=20.56%
# 2025-10-08 13:07:23,682 - INFO - TATAPOWER: Open_t-12=64.95, Close_t-1=90.35, Return=39.11%
# 2025-10-08 13:07:23,683 - INFO - TCS: Open_t-12=2505.00, Close_t-1=2431.80, Return=-2.92%
# 2025-10-08 13:07:23,684 - INFO - TECHM: Open_t-12=476.00, Close_t-1=459.15, Return=-3.54%
# 2025-10-08 13:07:23,685 - INFO - ULTRACEMCO: Open_t-12=3249.00, Close_t-1=3984.75, Return=22.65%
# 2025-10-08 13:07:23,685 - INFO - VEDL: Open_t-12=89.75, Close_t-1=274.95, Return=206.35%
# 2025-10-08 13:07:23,686 - INFO - WIPRO: Open_t-12=567.00, Close_t-1=515.70, Return=-9.05%
# 2025-10-08 13:07:23,687 - INFO - ZEEL: Open_t-12=384.00, Close_t-1=535.55, Return=39.47%
# 2025-10-08 13:07:23,691 - INFO - Selected 10 stocks for 2017-04 (Top Return: 206.35%)
# 2025-10-08 13:07:23,703 - INFO - Uninvested cash (will be carried forward): ₹3756.85
# 2025-10-08 13:07:23,717 - INFO - Capital: ₹5,000,000 → ₹5,092,907 (1.86%)
# 2025-10-08 13:07:23,718 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:23,718 - INFO - Processing 2017-05
# 2025-10-08 13:07:23,729 - INFO - ACC: Open_t-12=1442.00, Close_t-1=1626.55, Return=12.80%
# 2025-10-08 13:07:23,730 - INFO - ADANIPORTS: Open_t-12=237.00, Close_t-1=327.70, Return=38.27%
# 2025-10-08 13:07:23,731 - INFO - AMBUJACEM: Open_t-12=221.05, Close_t-1=245.90, Return=11.24%
# 2025-10-08 13:07:23,732 - INFO - ASIANPAINT: Open_t-12=864.00, Close_t-1=1120.45, Return=29.68%
# 2025-10-08 13:07:23,733 - INFO - AXISBANK: Open_t-12=474.35, Close_t-1=509.65, Return=7.44%
# 2025-10-08 13:07:23,734 - INFO - BAJAJ-AUTO: Open_t-12=2484.00, Close_t-1=2864.00, Return=15.30%
# 2025-10-08 13:07:23,735 - INFO - BANKBARODA: Open_t-12=157.80, Close_t-1=187.55, Return=18.85%
# 2025-10-08 13:07:23,735 - INFO - BHARTIARTL: Open_t-12=363.00, Close_t-1=355.50, Return=-2.07%
# 2025-10-08 13:07:23,736 - INFO - BHEL: Open_t-12=125.00, Close_t-1=175.70, Return=40.56%
# 2025-10-08 13:07:23,736 - INFO - BOSCHLTD: Open_t-12=19660.00, Close_t-1=22991.60, Return=16.95%
# 2025-10-08 13:07:23,737 - INFO - BPCL: Open_t-12=982.00, Close_t-1=719.25, Return=-26.76%
# 2025-10-08 13:07:23,740 - INFO - CAIRN: Open_t-12=145.00, Close_t-1=285.35, Return=96.79%
# 2025-10-08 13:07:23,741 - INFO - CIPLA: Open_t-12=536.95, Close_t-1=557.45, Return=3.82%
# 2025-10-08 13:07:23,742 - INFO - COALINDIA: Open_t-12=288.70, Close_t-1=276.65, Return=-4.17%
# 2025-10-08 13:07:23,744 - INFO - GAIL: Open_t-12=360.00, Close_t-1=423.95, Return=17.76%
# 2025-10-08 13:07:23,746 - INFO - HCLTECH: Open_t-12=750.00, Close_t-1=814.10, Return=8.55%
# 2025-10-08 13:07:23,747 - INFO - HDFC: Open_t-12=1091.45, Close_t-1=1537.15, Return=40.84%
# 2025-10-08 13:07:23,748 - INFO - HEROMOTOCO: Open_t-12=2893.00, Close_t-1=3318.60, Return=14.71%
# 2025-10-08 13:07:23,749 - INFO - HINDALCO: Open_t-12=96.40, Close_t-1=199.35, Return=106.79%
# 2025-10-08 13:07:23,750 - INFO - HINDUNILVR: Open_t-12=867.00, Close_t-1=934.95, Return=7.84%
# 2025-10-08 13:07:23,751 - INFO - ICICIBANK: Open_t-12=227.30, Close_t-1=278.50, Return=22.53%
# 2025-10-08 13:07:23,751 - INFO - IDEA: Open_t-12=118.00, Close_t-1=85.95, Return=-27.16%
# 2025-10-08 13:07:23,752 - INFO - INDUSINDBK: Open_t-12=1043.00, Close_t-1=1444.95, Return=38.54%
# 2025-10-08 13:07:23,752 - INFO - INFY: Open_t-12=1210.00, Close_t-1=918.95, Return=-24.05%
# 2025-10-08 13:07:23,753 - INFO - ITC: Open_t-12=323.25, Close_t-1=278.00, Return=-14.00%
# 2025-10-08 13:07:23,754 - INFO - KOTAKBANK: Open_t-12=714.20, Close_t-1=901.95, Return=26.29%
# 2025-10-08 13:07:23,759 - INFO - LT: Open_t-12=1246.00, Close_t-1=1749.80, Return=40.43%
# 2025-10-08 13:07:23,760 - INFO - LUPIN: Open_t-12=1616.00, Close_t-1=1338.35, Return=-17.18%
# 2025-10-08 13:07:23,762 - INFO - M&M: Open_t-12=1319.00, Close_t-1=1335.55, Return=1.25%
# 2025-10-08 13:07:23,763 - INFO - MARUTI: Open_t-12=3799.90, Close_t-1=6524.85, Return=71.71%
# 2025-10-08 13:07:23,764 - INFO - NTPC: Open_t-12=139.30, Close_t-1=164.50, Return=18.09%
# 2025-10-08 13:07:23,765 - INFO - ONGC: Open_t-12=218.00, Close_t-1=186.55, Return=-14.43%
# 2025-10-08 13:07:23,766 - INFO - PNB: Open_t-12=86.80, Close_t-1=168.85, Return=94.53%
# 2025-10-08 13:07:23,767 - INFO - POWERGRID: Open_t-12=143.00, Close_t-1=208.00, Return=45.45%
# 2025-10-08 13:07:23,767 - INFO - RELIANCE: Open_t-12=979.00, Close_t-1=1395.20, Return=42.51%
# 2025-10-08 13:07:23,768 - INFO - SBIN: Open_t-12=187.60, Close_t-1=289.75, Return=54.45%
# 2025-10-08 13:07:23,769 - INFO - SUNPHARMA: Open_t-12=813.75, Close_t-1=641.95, Return=-21.11%
# 2025-10-08 13:07:23,770 - INFO - TATAMOTORS: Open_t-12=407.95, Close_t-1=458.90, Return=12.49%
# 2025-10-08 13:07:23,770 - INFO - TATAPOWER: Open_t-12=70.45, Close_t-1=84.30, Return=19.66%
# 2025-10-08 13:07:23,773 - INFO - TCS: Open_t-12=2529.00, Close_t-1=2273.15, Return=-10.12%
# 2025-10-08 13:07:23,774 - INFO - TECHM: Open_t-12=485.00, Close_t-1=416.95, Return=-14.03%
# 2025-10-08 13:07:23,775 - INFO - ULTRACEMCO: Open_t-12=3170.60, Close_t-1=4248.95, Return=34.01%
# 2025-10-08 13:07:23,776 - INFO - VEDL: Open_t-12=102.50, Close_t-1=243.55, Return=137.61%
# 2025-10-08 13:07:23,778 - INFO - WIPRO: Open_t-12=551.00, Close_t-1=494.25, Return=-10.30%
# 2025-10-08 13:07:23,779 - INFO - ZEEL: Open_t-12=414.00, Close_t-1=526.85, Return=27.26%
# 2025-10-08 13:07:23,782 - INFO - Selected 10 stocks for 2017-05 (Top Return: 137.61%)
# 2025-10-08 13:07:23,785 - WARNING - No price data for CAIRN - skipping
# 2025-10-08 13:07:23,791 - INFO - Uninvested cash (will be carried forward): ₹517792.25
# 2025-10-08 13:07:23,801 - INFO - Capital: ₹5,092,907 → ₹4,945,727 (-2.89%)
# 2025-10-08 13:07:23,801 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:23,802 - INFO - Processing 2017-06
# 2025-10-08 13:07:23,813 - INFO - ACC: Open_t-12=1535.00, Close_t-1=1637.05, Return=6.65%
# 2025-10-08 13:07:23,814 - INFO - ADANIPORTS: Open_t-12=192.85, Close_t-1=339.00, Return=75.78%
# 2025-10-08 13:07:23,815 - INFO - AMBUJACEM: Open_t-12=229.00, Close_t-1=241.25, Return=5.35%
# 2025-10-08 13:07:23,816 - INFO - ASIANPAINT: Open_t-12=989.05, Close_t-1=1151.20, Return=16.39%
# 2025-10-08 13:07:23,817 - INFO - AXISBANK: Open_t-12=524.85, Close_t-1=514.05, Return=-2.06%
# 2025-10-08 13:07:23,818 - INFO - BAJAJ-AUTO: Open_t-12=2635.00, Close_t-1=2845.95, Return=8.01%
# 2025-10-08 13:07:23,818 - INFO - BANKBARODA: Open_t-12=143.30, Close_t-1=178.05, Return=24.25%
# 2025-10-08 13:07:23,819 - INFO - BHARTIARTL: Open_t-12=353.55, Close_t-1=371.55, Return=5.09%
# 2025-10-08 13:07:23,819 - INFO - BHEL: Open_t-12=122.00, Close_t-1=138.20, Return=13.28%
# 2025-10-08 13:07:23,820 - INFO - BOSCHLTD: Open_t-12=22300.05, Close_t-1=23337.95, Return=4.65%
# 2025-10-08 13:07:23,820 - INFO - BPCL: Open_t-12=995.00, Close_t-1=742.65, Return=-25.36%
# 2025-10-08 13:07:23,823 - INFO - CIPLA: Open_t-12=474.70, Close_t-1=516.35, Return=8.77%
# 2025-10-08 13:07:23,824 - INFO - COALINDIA: Open_t-12=292.05, Close_t-1=262.55, Return=-10.10%
# 2025-10-08 13:07:23,826 - INFO - GAIL: Open_t-12=370.45, Close_t-1=414.00, Return=11.76%
# 2025-10-08 13:07:23,827 - INFO - HCLTECH: Open_t-12=744.00, Close_t-1=864.25, Return=16.16%
# 2025-10-08 13:07:23,829 - INFO - HDFC: Open_t-12=1242.15, Close_t-1=1569.85, Return=26.38%
# 2025-10-08 13:07:23,830 - INFO - HEROMOTOCO: Open_t-12=3123.70, Close_t-1=3745.45, Return=19.90%
# 2025-10-08 13:07:23,831 - INFO - HINDALCO: Open_t-12=105.35, Close_t-1=200.70, Return=90.51%
# 2025-10-08 13:07:23,832 - INFO - HINDUNILVR: Open_t-12=852.15, Close_t-1=1067.00, Return=25.21%
# 2025-10-08 13:07:23,833 - INFO - ICICIBANK: Open_t-12=243.90, Close_t-1=326.45, Return=33.85%
# 2025-10-08 13:07:23,833 - INFO - IDEA: Open_t-12=115.75, Close_t-1=80.00, Return=-30.89%
# 2025-10-08 13:07:23,834 - INFO - INDUSINDBK: Open_t-12=1103.00, Close_t-1=1480.70, Return=34.24%
# 2025-10-08 13:07:23,835 - INFO - INFY: Open_t-12=1246.05, Close_t-1=977.05, Return=-21.59%
# 2025-10-08 13:07:23,835 - INFO - ITC: Open_t-12=353.00, Close_t-1=311.80, Return=-11.67%
# 2025-10-08 13:07:23,836 - INFO - KOTAKBANK: Open_t-12=749.75, Close_t-1=966.05, Return=28.85%
# 2025-10-08 13:07:23,836 - INFO - LT: Open_t-12=1470.05, Close_t-1=1760.70, Return=19.77%
# 2025-10-08 13:07:23,837 - INFO - LUPIN: Open_t-12=1479.65, Close_t-1=1161.00, Return=-21.54%
# 2025-10-08 13:07:23,841 - INFO - M&M: Open_t-12=1329.00, Close_t-1=1416.95, Return=6.62%
# 2025-10-08 13:07:23,843 - INFO - MARUTI: Open_t-12=4170.70, Close_t-1=7211.00, Return=72.90%
# 2025-10-08 13:07:23,844 - INFO - NTPC: Open_t-12=142.90, Close_t-1=160.20, Return=12.11%
# 2025-10-08 13:07:23,846 - INFO - ONGC: Open_t-12=211.40, Close_t-1=177.00, Return=-16.27%
# 2025-10-08 13:07:23,847 - INFO - PNB: Open_t-12=79.00, Close_t-1=150.50, Return=90.51%
# 2025-10-08 13:07:23,848 - INFO - POWERGRID: Open_t-12=150.60, Close_t-1=207.95, Return=38.08%
# 2025-10-08 13:07:23,848 - INFO - RELIANCE: Open_t-12=957.95, Close_t-1=1340.70, Return=39.96%
# 2025-10-08 13:07:23,849 - INFO - SBIN: Open_t-12=205.95, Close_t-1=288.30, Return=39.99%
# 2025-10-08 13:07:23,850 - INFO - SUNPHARMA: Open_t-12=767.05, Close_t-1=501.60, Return=-34.61%
# 2025-10-08 13:07:23,851 - INFO - TATAMOTORS: Open_t-12=455.75, Close_t-1=476.15, Return=4.48%
# 2025-10-08 13:07:23,851 - INFO - TATAPOWER: Open_t-12=74.95, Close_t-1=81.00, Return=8.07%
# 2025-10-08 13:07:23,852 - INFO - TCS: Open_t-12=2571.20, Close_t-1=2546.60, Return=-0.96%
# 2025-10-08 13:07:23,853 - INFO - TECHM: Open_t-12=541.00, Close_t-1=390.00, Return=-27.91%
# 2025-10-08 13:07:23,853 - INFO - ULTRACEMCO: Open_t-12=3226.70, Close_t-1=4195.20, Return=30.02%
# 2025-10-08 13:07:23,856 - INFO - VEDL: Open_t-12=109.00, Close_t-1=238.65, Return=118.94%
# 2025-10-08 13:07:23,857 - INFO - WIPRO: Open_t-12=545.60, Close_t-1=535.50, Return=-1.85%
# 2025-10-08 13:07:23,859 - INFO - ZEEL: Open_t-12=445.70, Close_t-1=514.85, Return=15.51%
# 2025-10-08 13:07:23,862 - INFO - Selected 10 stocks for 2017-06 (Top Return: 118.94%)
# 2025-10-08 13:07:23,870 - INFO - Uninvested cash (will be carried forward): ₹4080.35
# 2025-10-08 13:07:23,884 - INFO - Capital: ₹4,945,727 → ₹4,898,916 (-0.95%)
# 2025-10-08 13:07:23,885 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:23,885 - INFO - Processing 2017-07
# 2025-10-08 13:07:23,893 - INFO - ACC: Open_t-12=1618.35, Close_t-1=1568.05, Return=-3.11%
# 2025-10-08 13:07:23,895 - INFO - ADANIPORTS: Open_t-12=205.10, Close_t-1=363.05, Return=77.01%
# 2025-10-08 13:07:23,896 - INFO - AMBUJACEM: Open_t-12=255.70, Close_t-1=246.55, Return=-3.58%
# 2025-10-08 13:07:23,898 - INFO - ASIANPAINT: Open_t-12=1002.80, Close_t-1=1102.95, Return=9.99%
# 2025-10-08 13:07:23,899 - INFO - AXISBANK: Open_t-12=535.80, Close_t-1=517.35, Return=-3.44%
# 2025-10-08 13:07:23,900 - INFO - BAJAJ-AUTO: Open_t-12=2697.50, Close_t-1=2791.20, Return=3.47%
# 2025-10-08 13:07:23,900 - INFO - BANKBARODA: Open_t-12=154.05, Close_t-1=161.65, Return=4.93%
# 2025-10-08 13:07:23,901 - INFO - BHARTIARTL: Open_t-12=365.80, Close_t-1=379.70, Return=3.80%
# 2025-10-08 13:07:23,902 - INFO - BHEL: Open_t-12=129.00, Close_t-1=135.30, Return=4.88%
# 2025-10-08 13:07:23,902 - INFO - BOSCHLTD: Open_t-12=22700.00, Close_t-1=23327.25, Return=2.76%
# 2025-10-08 13:07:23,903 - INFO - BPCL: Open_t-12=1075.00, Close_t-1=639.40, Return=-40.52%
# 2025-10-08 13:07:23,903 - INFO - CIPLA: Open_t-12=502.00, Close_t-1=555.60, Return=10.68%
# 2025-10-08 13:07:23,904 - INFO - COALINDIA: Open_t-12=313.00, Close_t-1=244.25, Return=-21.96%
# 2025-10-08 13:07:23,907 - INFO - GAIL: Open_t-12=388.00, Close_t-1=361.45, Return=-6.84%
# 2025-10-08 13:07:23,907 - INFO - HCLTECH: Open_t-12=735.00, Close_t-1=850.90, Return=15.77%
# 2025-10-08 13:07:23,908 - INFO - HDFC: Open_t-12=1253.50, Close_t-1=1614.95, Return=28.84%
# 2025-10-08 13:07:23,910 - INFO - HEROMOTOCO: Open_t-12=3188.70, Close_t-1=3701.35, Return=16.08%
# 2025-10-08 13:07:23,911 - INFO - HINDALCO: Open_t-12=124.00, Close_t-1=190.95, Return=53.99%
# 2025-10-08 13:07:23,913 - INFO - HINDUNILVR: Open_t-12=898.60, Close_t-1=1079.60, Return=20.14%
# 2025-10-08 13:07:23,914 - INFO - ICICIBANK: Open_t-12=241.70, Close_t-1=290.15, Return=20.05%
# 2025-10-08 13:07:23,915 - INFO - IDEA: Open_t-12=107.00, Close_t-1=85.25, Return=-20.33%
# 2025-10-08 13:07:23,916 - INFO - INDUSINDBK: Open_t-12=1125.00, Close_t-1=1478.95, Return=31.46%
# 2025-10-08 13:07:23,917 - INFO - INFY: Open_t-12=1180.00, Close_t-1=935.55, Return=-20.72%
# 2025-10-08 13:07:23,918 - INFO - ITC: Open_t-12=243.30, Close_t-1=323.65, Return=33.03%
# 2025-10-08 13:07:23,918 - INFO - KOTAKBANK: Open_t-12=764.00, Close_t-1=955.75, Return=25.10%
# 2025-10-08 13:07:23,919 - INFO - LT: Open_t-12=1504.80, Close_t-1=1687.60, Return=12.15%
# 2025-10-08 13:07:23,919 - INFO - LUPIN: Open_t-12=1545.00, Close_t-1=1059.85, Return=-31.40%
# 2025-10-08 13:07:23,920 - INFO - M&M: Open_t-12=1433.00, Close_t-1=1348.60, Return=-5.89%
# 2025-10-08 13:07:23,920 - INFO - MARUTI: Open_t-12=4188.60, Close_t-1=7217.60, Return=72.32%
# 2025-10-08 13:07:23,923 - INFO - NTPC: Open_t-12=155.30, Close_t-1=158.95, Return=2.35%
# 2025-10-08 13:07:23,925 - INFO - ONGC: Open_t-12=216.90, Close_t-1=157.30, Return=-27.48%
# 2025-10-08 13:07:23,927 - INFO - PNB: Open_t-12=106.10, Close_t-1=137.30, Return=29.41%
# 2025-10-08 13:07:23,929 - INFO - POWERGRID: Open_t-12=164.00, Close_t-1=210.55, Return=28.38%
# 2025-10-08 13:07:23,930 - INFO - RELIANCE: Open_t-12=972.75, Close_t-1=1380.00, Return=41.87%
# 2025-10-08 13:07:23,931 - INFO - SBIN: Open_t-12=220.80, Close_t-1=273.65, Return=23.94%
# 2025-10-08 13:07:23,932 - INFO - SUNPHARMA: Open_t-12=769.00, Close_t-1=555.70, Return=-27.74%
# 2025-10-08 13:07:23,933 - INFO - TATAMOTORS: Open_t-12=463.60, Close_t-1=432.55, Return=-6.70%
# 2025-10-08 13:07:23,934 - INFO - TATAPOWER: Open_t-12=74.00, Close_t-1=80.55, Return=8.85%
# 2025-10-08 13:07:23,934 - INFO - TCS: Open_t-12=2562.00, Close_t-1=2362.35, Return=-7.79%
# 2025-10-08 13:07:23,935 - INFO - TECHM: Open_t-12=508.20, Close_t-1=382.00, Return=-24.83%
# 2025-10-08 13:07:23,936 - INFO - ULTRACEMCO: Open_t-12=3410.00, Close_t-1=3959.10, Return=16.10%
# 2025-10-08 13:07:23,936 - INFO - VEDL: Open_t-12=132.95, Close_t-1=249.05, Return=87.33%
# 2025-10-08 13:07:23,937 - INFO - WIPRO: Open_t-12=559.75, Close_t-1=258.35, Return=-53.85%
# 2025-10-08 13:07:23,939 - INFO - ZEEL: Open_t-12=459.50, Close_t-1=491.35, Return=6.93%
# 2025-10-08 13:07:23,941 - INFO - Selected 10 stocks for 2017-07 (Top Return: 87.33%)
# 2025-10-08 13:07:23,951 - INFO - Uninvested cash (will be carried forward): ₹7071.05
# 2025-10-08 13:07:23,960 - INFO - Capital: ₹4,898,916 → ₹5,279,638 (7.77%)
# 2025-10-08 13:07:23,961 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:23,963 - INFO - Processing 2017-08
# 2025-10-08 13:07:23,973 - INFO - ACC: Open_t-12=1695.55, Close_t-1=1733.20, Return=2.22%
# 2025-10-08 13:07:23,974 - INFO - ADANIPORTS: Open_t-12=234.45, Close_t-1=395.90, Return=68.86%
# 2025-10-08 13:07:23,976 - INFO - AMBUJACEM: Open_t-12=271.65, Close_t-1=263.15, Return=-3.13%
# 2025-10-08 13:07:23,978 - INFO - ASIANPAINT: Open_t-12=1119.60, Close_t-1=1161.70, Return=3.76%
# 2025-10-08 13:07:23,980 - INFO - AXISBANK: Open_t-12=546.25, Close_t-1=519.80, Return=-4.84%
# 2025-10-08 13:07:23,981 - INFO - BAJAJ-AUTO: Open_t-12=2710.10, Close_t-1=2808.55, Return=3.63%
# 2025-10-08 13:07:23,981 - INFO - BANKBARODA: Open_t-12=153.00, Close_t-1=166.05, Return=8.53%
# 2025-10-08 13:07:23,982 - INFO - BHARTIARTL: Open_t-12=363.45, Close_t-1=418.95, Return=15.27%
# 2025-10-08 13:07:23,983 - INFO - BHEL: Open_t-12=146.00, Close_t-1=145.10, Return=-0.62%
# 2025-10-08 13:07:23,984 - INFO - BOSCHLTD: Open_t-12=25025.00, Close_t-1=24178.10, Return=-3.38%
# 2025-10-08 13:07:23,984 - INFO - BPCL: Open_t-12=596.95, Close_t-1=471.15, Return=-21.07%
# 2025-10-08 13:07:23,985 - INFO - CIPLA: Open_t-12=528.80, Close_t-1=560.10, Return=5.92%
# 2025-10-08 13:07:23,985 - INFO - COALINDIA: Open_t-12=329.30, Close_t-1=249.10, Return=-24.35%
# 2025-10-08 13:07:23,986 - INFO - GAIL: Open_t-12=382.00, Close_t-1=376.75, Return=-1.37%
# 2025-10-08 13:07:23,987 - INFO - HCLTECH: Open_t-12=753.00, Close_t-1=892.90, Return=18.58%
# 2025-10-08 13:07:23,987 - INFO - HDFC: Open_t-12=1385.00, Close_t-1=1789.25, Return=29.19%
# 2025-10-08 13:07:23,991 - INFO - HEROMOTOCO: Open_t-12=3220.70, Close_t-1=3655.75, Return=13.51%
# 2025-10-08 13:07:23,992 - INFO - HINDALCO: Open_t-12=134.50, Close_t-1=219.65, Return=63.31%
# 2025-10-08 13:07:23,993 - INFO - HINDUNILVR: Open_t-12=930.00, Close_t-1=1155.75, Return=24.27%
# 2025-10-08 13:07:23,994 - INFO - ICICIBANK: Open_t-12=255.90, Close_t-1=302.60, Return=18.25%
# 2025-10-08 13:07:23,996 - INFO - IDEA: Open_t-12=105.05, Close_t-1=92.45, Return=-11.99%
# 2025-10-08 13:07:23,997 - INFO - INDUSINDBK: Open_t-12=1173.00, Close_t-1=1645.75, Return=40.30%
# 2025-10-08 13:07:23,998 - INFO - INFY: Open_t-12=1071.50, Close_t-1=1011.20, Return=-5.63%
# 2025-10-08 13:07:23,999 - INFO - ITC: Open_t-12=252.00, Close_t-1=285.25, Return=13.19%
# 2025-10-08 13:07:24,000 - INFO - KOTAKBANK: Open_t-12=766.00, Close_t-1=1021.65, Return=33.37%
# 2025-10-08 13:07:24,000 - INFO - LT: Open_t-12=1559.05, Close_t-1=1193.95, Return=-23.42%
# 2025-10-08 13:07:24,001 - INFO - LUPIN: Open_t-12=1743.00, Close_t-1=1032.00, Return=-40.79%
# 2025-10-08 13:07:24,002 - INFO - M&M: Open_t-12=1472.90, Close_t-1=1403.30, Return=-4.73%
# 2025-10-08 13:07:24,002 - INFO - MARUTI: Open_t-12=4798.95, Close_t-1=7750.05, Return=61.49%
# 2025-10-08 13:07:24,003 - INFO - NTPC: Open_t-12=158.60, Close_t-1=164.20, Return=3.53%
# 2025-10-08 13:07:24,003 - INFO - ONGC: Open_t-12=222.30, Close_t-1=169.40, Return=-23.80%
# 2025-10-08 13:07:24,004 - INFO - PNB: Open_t-12=125.50, Close_t-1=162.30, Return=29.32%
# 2025-10-08 13:07:24,007 - INFO - POWERGRID: Open_t-12=176.00, Close_t-1=223.30, Return=26.88%
# 2025-10-08 13:07:24,008 - INFO - RELIANCE: Open_t-12=1018.00, Close_t-1=1615.20, Return=58.66%
# 2025-10-08 13:07:24,010 - INFO - SBIN: Open_t-12=230.80, Close_t-1=312.50, Return=35.40%
# 2025-10-08 13:07:24,011 - INFO - SUNPHARMA: Open_t-12=837.90, Close_t-1=531.65, Return=-36.55%
# 2025-10-08 13:07:24,013 - INFO - TATAMOTORS: Open_t-12=506.80, Close_t-1=444.60, Return=-12.27%
# 2025-10-08 13:07:24,014 - INFO - TATAPOWER: Open_t-12=72.55, Close_t-1=82.00, Return=13.03%
# 2025-10-08 13:07:24,014 - INFO - TCS: Open_t-12=2632.00, Close_t-1=2491.80, Return=-5.33%
# 2025-10-08 13:07:24,015 - INFO - TECHM: Open_t-12=485.20, Close_t-1=385.85, Return=-20.48%
# 2025-10-08 13:07:24,016 - INFO - ULTRACEMCO: Open_t-12=3730.00, Close_t-1=4056.90, Return=8.76%
# 2025-10-08 13:07:24,017 - INFO - VEDL: Open_t-12=163.10, Close_t-1=279.85, Return=71.58%
# 2025-10-08 13:07:24,017 - INFO - WIPRO: Open_t-12=545.05, Close_t-1=288.45, Return=-47.08%
# 2025-10-08 13:07:24,018 - INFO - ZEEL: Open_t-12=494.10, Close_t-1=541.75, Return=9.64%
# 2025-10-08 13:07:24,019 - INFO - Selected 10 stocks for 2017-08 (Top Return: 71.58%)
# 2025-10-08 13:07:24,032 - INFO - Uninvested cash (will be carried forward): ₹5909.55
# 2025-10-08 13:07:24,042 - INFO - Capital: ₹5,279,638 → ₹5,207,439 (-1.37%)
# 2025-10-08 13:07:24,044 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:24,045 - INFO - Processing 2017-09
# 2025-10-08 13:07:24,052 - INFO - ACC: Open_t-12=1668.00, Close_t-1=1800.25, Return=7.93%
# 2025-10-08 13:07:24,053 - INFO - ADANIPORTS: Open_t-12=263.15, Close_t-1=392.95, Return=49.33%
# 2025-10-08 13:07:24,053 - INFO - AMBUJACEM: Open_t-12=273.70, Close_t-1=280.35, Return=2.43%
# 2025-10-08 13:07:24,054 - INFO - ASIANPAINT: Open_t-12=1159.85, Close_t-1=1168.55, Return=0.75%
# 2025-10-08 13:07:24,058 - INFO - AXISBANK: Open_t-12=597.05, Close_t-1=500.35, Return=-16.20%
# 2025-10-08 13:07:24,060 - INFO - BAJAJ-AUTO: Open_t-12=2978.50, Close_t-1=2814.50, Return=-5.51%
# 2025-10-08 13:07:24,061 - INFO - BANKBARODA: Open_t-12=163.50, Close_t-1=137.85, Return=-15.69%
# 2025-10-08 13:07:24,063 - INFO - BHARTIARTL: Open_t-12=330.00, Close_t-1=427.70, Return=29.61%
# 2025-10-08 13:07:24,063 - INFO - BHEL: Open_t-12=139.10, Close_t-1=128.90, Return=-7.33%
# 2025-10-08 13:07:24,064 - INFO - BOSCHLTD: Open_t-12=24280.00, Close_t-1=21986.80, Return=-9.44%
# 2025-10-08 13:07:24,065 - INFO - BPCL: Open_t-12=600.30, Close_t-1=529.00, Return=-11.88%
# 2025-10-08 13:07:24,066 - INFO - CIPLA: Open_t-12=575.00, Close_t-1=571.90, Return=-0.54%
# 2025-10-08 13:07:24,067 - INFO - COALINDIA: Open_t-12=334.10, Close_t-1=237.40, Return=-28.94%
# 2025-10-08 13:07:24,068 - INFO - GAIL: Open_t-12=383.00, Close_t-1=378.30, Return=-1.23%
# 2025-10-08 13:07:24,068 - INFO - HCLTECH: Open_t-12=781.30, Close_t-1=865.30, Return=10.75%
# 2025-10-08 13:07:24,069 - INFO - HDFC: Open_t-12=1412.00, Close_t-1=1776.90, Return=25.84%
# 2025-10-08 13:07:24,070 - INFO - HEROMOTOCO: Open_t-12=3560.00, Close_t-1=3995.10, Return=12.22%
# 2025-10-08 13:07:24,070 - INFO - HINDALCO: Open_t-12=159.00, Close_t-1=238.00, Return=49.69%
# 2025-10-08 13:07:24,073 - INFO - HINDUNILVR: Open_t-12=917.10, Close_t-1=1219.75, Return=33.00%
# 2025-10-08 13:07:24,074 - INFO - ICICIBANK: Open_t-12=258.75, Close_t-1=298.05, Return=15.19%
# 2025-10-08 13:07:24,076 - INFO - IDEA: Open_t-12=93.10, Close_t-1=90.65, Return=-2.63%
# 2025-10-08 13:07:24,077 - INFO - INDUSINDBK: Open_t-12=1191.75, Close_t-1=1656.75, Return=39.02%
# 2025-10-08 13:07:24,078 - INFO - INFY: Open_t-12=1038.00, Close_t-1=914.95, Return=-11.85%
# 2025-10-08 13:07:24,080 - INFO - ITC: Open_t-12=261.00, Close_t-1=282.25, Return=8.14%
# 2025-10-08 13:07:24,081 - INFO - KOTAKBANK: Open_t-12=813.00, Close_t-1=976.00, Return=20.05%
# 2025-10-08 13:07:24,082 - INFO - LT: Open_t-12=1513.00, Close_t-1=1136.30, Return=-24.90%
# 2025-10-08 13:07:24,083 - INFO - LUPIN: Open_t-12=1482.20, Close_t-1=979.45, Return=-33.92%
# 2025-10-08 13:07:24,083 - INFO - M&M: Open_t-12=1439.00, Close_t-1=1344.80, Return=-6.55%
# 2025-10-08 13:07:24,084 - INFO - MARUTI: Open_t-12=5074.00, Close_t-1=7700.30, Return=51.76%
# 2025-10-08 13:07:24,085 - INFO - NTPC: Open_t-12=159.70, Close_t-1=168.75, Return=5.67%
# 2025-10-08 13:07:24,085 - INFO - ONGC: Open_t-12=237.00, Close_t-1=156.95, Return=-33.78%
# 2025-10-08 13:07:24,086 - INFO - PNB: Open_t-12=127.25, Close_t-1=143.80, Return=13.01%
# 2025-10-08 13:07:24,087 - INFO - POWERGRID: Open_t-12=183.50, Close_t-1=219.25, Return=19.48%
# 2025-10-08 13:07:24,087 - INFO - RELIANCE: Open_t-12=1053.00, Close_t-1=1594.50, Return=51.42%
# 2025-10-08 13:07:24,090 - INFO - SBIN: Open_t-12=251.95, Close_t-1=277.75, Return=10.24%
# 2025-10-08 13:07:24,091 - INFO - SUNPHARMA: Open_t-12=775.60, Close_t-1=481.15, Return=-37.96%
# 2025-10-08 13:07:24,093 - INFO - TATAMOTORS: Open_t-12=540.50, Close_t-1=376.55, Return=-30.33%
# 2025-10-08 13:07:24,095 - INFO - TATAPOWER: Open_t-12=79.80, Close_t-1=79.25, Return=-0.69%
# 2025-10-08 13:07:24,097 - INFO - TCS: Open_t-12=2524.90, Close_t-1=2496.35, Return=-1.13%
# 2025-10-08 13:07:24,098 - INFO - TECHM: Open_t-12=470.00, Close_t-1=428.15, Return=-8.90%
# 2025-10-08 13:07:24,099 - INFO - ULTRACEMCO: Open_t-12=3960.00, Close_t-1=4000.40, Return=1.02%
# 2025-10-08 13:07:24,099 - INFO - VEDL: Open_t-12=169.35, Close_t-1=308.90, Return=82.40%
# 2025-10-08 13:07:24,100 - INFO - WIPRO: Open_t-12=489.70, Close_t-1=299.10, Return=-38.92%
# 2025-10-08 13:07:24,101 - INFO - ZEEL: Open_t-12=544.85, Close_t-1=519.50, Return=-4.65%
# 2025-10-08 13:07:24,103 - INFO - Selected 10 stocks for 2017-09 (Top Return: 82.40%)
# 2025-10-08 13:07:24,117 - INFO - Uninvested cash (will be carried forward): ₹10246.10
# 2025-10-08 13:07:24,127 - INFO - Capital: ₹5,207,439 → ₹4,856,752 (-6.73%)
# 2025-10-08 13:07:24,129 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:24,130 - INFO - Processing 2017-10
# 2025-10-08 13:07:24,136 - INFO - ACC: Open_t-12=1615.00, Close_t-1=1656.90, Return=2.59%
# 2025-10-08 13:07:24,137 - INFO - ADANIPORTS: Open_t-12=260.70, Close_t-1=376.75, Return=44.51%
# 2025-10-08 13:07:24,140 - INFO - AMBUJACEM: Open_t-12=253.40, Close_t-1=266.45, Return=5.15%
# 2025-10-08 13:07:24,141 - INFO - ASIANPAINT: Open_t-12=1170.00, Close_t-1=1131.70, Return=-3.27%
# 2025-10-08 13:07:24,145 - INFO - AXISBANK: Open_t-12=542.95, Close_t-1=509.15, Return=-6.23%
# 2025-10-08 13:07:24,147 - INFO - BAJAJ-AUTO: Open_t-12=2830.00, Close_t-1=3109.40, Return=9.87%
# 2025-10-08 13:07:24,148 - INFO - BANKBARODA: Open_t-12=168.10, Close_t-1=137.60, Return=-18.14%
# 2025-10-08 13:07:24,149 - INFO - BHARTIARTL: Open_t-12=314.00, Close_t-1=389.45, Return=24.03%
# 2025-10-08 13:07:24,150 - INFO - BHEL: Open_t-12=136.60, Close_t-1=83.95, Return=-38.54%
# 2025-10-08 13:07:24,150 - INFO - BOSCHLTD: Open_t-12=22930.00, Close_t-1=20545.10, Return=-10.40%
# 2025-10-08 13:07:24,151 - INFO - BPCL: Open_t-12=616.00, Close_t-1=471.30, Return=-23.49%
# 2025-10-08 13:07:24,153 - INFO - CIPLA: Open_t-12=584.70, Close_t-1=586.10, Return=0.24%
# 2025-10-08 13:07:24,154 - INFO - COALINDIA: Open_t-12=323.10, Close_t-1=270.85, Return=-16.17%
# 2025-10-08 13:07:24,156 - INFO - GAIL: Open_t-12=372.95, Close_t-1=419.05, Return=12.36%
# 2025-10-08 13:07:24,158 - INFO - GRASIM: Open_t-12=1015.00, Close_t-1=1133.95, Return=11.72%
# 2025-10-08 13:07:24,159 - INFO - HCLTECH: Open_t-12=805.00, Close_t-1=874.80, Return=8.67%
# 2025-10-08 13:07:24,161 - INFO - HDFC: Open_t-12=1401.00, Close_t-1=1742.15, Return=24.35%
# 2025-10-08 13:07:24,162 - INFO - HEROMOTOCO: Open_t-12=3436.40, Close_t-1=3774.55, Return=9.84%
# 2025-10-08 13:07:24,163 - INFO - HINDALCO: Open_t-12=154.50, Close_t-1=240.60, Return=55.73%
# 2025-10-08 13:07:24,164 - INFO - HINDUNILVR: Open_t-12=878.00, Close_t-1=1173.90, Return=33.70%
# 2025-10-08 13:07:24,165 - INFO - ICICIBANK: Open_t-12=251.00, Close_t-1=276.60, Return=10.20%
# 2025-10-08 13:07:24,166 - INFO - IDEA: Open_t-12=80.10, Close_t-1=77.45, Return=-3.31%
# 2025-10-08 13:07:24,167 - INFO - INDUSINDBK: Open_t-12=1201.00, Close_t-1=1682.20, Return=40.07%
- INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:24,219 - INFO - Processing 2017-11
# 2025-10-08 13:07:24,228 - INFO - ACC: Open_t-12=1514.70, Close_t-1=1809.50, Return=19.46%
# 2025-10-08 13:07:24,230 - INFO - ADANIPORTS: Open_t-12=307.00, Close_t-1=430.35, Return=40.18%
# 2025-10-08 13:07:24,231 - INFO - AMBUJACEM: Open_t-12=239.70, Close_t-1=281.50, Return=17.44%
# 2025-10-08 13:07:24,232 - INFO - ASIANPAINT: Open_t-12=1077.10, Close_t-1=1180.85, Return=9.63%
# 2025-10-08 13:07:24,233 - INFO - AXISBANK: Open_t-12=488.05, Close_t-1=523.15, Return=7.19%
# 2025-10-08 13:07:24,234 - INFO - BAJAJ-AUTO: Open_t-12=2830.40, Close_t-1=3257.10, Return=15.08%
# 2025-10-08 13:07:24,235 - INFO - BANKBARODA: Open_t-12=156.60, Close_t-1=169.90, Return=8.49%
# 2025-10-08 13:07:24,235 - INFO - BHARTIARTL: Open_t-12=318.00, Close_t-1=497.20, Return=56.35%
# 2025-10-08 13:07:24,236 - INFO - BHEL: Open_t-12=140.00, Close_t-1=98.00, Return=-30.00%
# 2025-10-08 13:07:24,236 - INFO - BOSCHLTD: Open_t-12=21900.00, Close_t-1=21012.20, Return=-4.05%
# 2025-10-08 13:07:24,237 - INFO - BPCL: Open_t-12=671.05, Close_t-1=541.60, Return=-19.29%
# 2025-10-08 13:07:24,240 - INFO - CIPLA: Open_t-12=579.45, Close_t-1=627.60, Return=8.31%
# 2025-10-08 13:07:24,241 - INFO - COALINDIA: Open_t-12=326.50, Close_t-1=286.45, Return=-12.27%
# 2025-10-08 13:07:24,242 - INFO - GAIL: Open_t-12=432.80, Close_t-1=465.20, Return=7.49%
# 2025-10-08 13:07:24,243 - INFO - GRASIM: Open_t-12=976.90, Close_t-1=1227.10, Return=25.61%
# 2025-10-08 13:07:24,245 - INFO - HCLTECH: Open_t-12=771.80, Close_t-1=855.80, Return=10.88%
# 2025-10-08 13:07:24,247 - INFO - HDFC: Open_t-12=1382.60, Close_t-1=1707.40, Return=23.49%
# 2025-10-08 13:07:24,248 - INFO - HEROMOTOCO: Open_t-12=3380.00, Close_t-1=3849.90, Return=13.90%
# 2025-10-08 13:07:24,249 - INFO - HINDALCO: Open_t-12=150.50, Close_t-1=267.40, Return=77.67%
# 2025-10-08 13:07:24,250 - INFO - HINDUNILVR: Open_t-12=835.00, Close_t-1=1237.45, Return=48.20%
# 2025-10-08 13:07:24,251 - INFO - ICICIBANK: Open_t-12=279.45, Close_t-1=300.10, Return=7.39%
# 2025-10-08 13:07:24,251 - INFO - IDEA: Open_t-12=76.80, Close_t-1=92.85, Return=20.90%
# 2025-10-08 13:07:24,252 - INFO - INDUSINDBK: Open_t-12=1197.00, Close_t-1=1627.15, Return=35.94%
# 2025-10-08 13:07:24,252 - INFO - INFY: Open_t-12=1006.80, Close_t-1=921.85, Return=-8.44%
# 2025-10-08 13:07:24,253 - INFO - ITC: Open_t-12=242.80, Close_t-1=265.70, Return=9.43%
# 2025-10-08 13:07:24,253 - INFO - KOTAKBANK: Open_t-12=819.90, Close_t-1=1025.05, Return=25.02%
# 2025-10-08 13:07:24,495 - INFO - BPCL: Open_t-12=682.05, Close_t-1=492.30, Return=-27.82%
# 2025-10-08 13:07:24,496 - INFO - CIPLA: Open_t-12=573.00, Close_t-1=592.15, Return=3.34%
# 2025-10-08 13:07:24,498 - INFO - COALINDIA: Open_t-12=310.00, Close_t-1=299.55, Return=-3.37%
# 2025-10-08 13:07:24,499 - INFO - GAIL: Open_t-12=469.70, Close_t-1=478.60, Return=1.89%
# ...
# 2025-10-08 13:07:35,678 - INFO - VEDL: Open_t-12=472.00, Close_t-1=435.55, Return=-7.72%
# 2025-10-08 13:07:35,679 - INFO - WIPRO: Open_t-12=450.20, Close_t-1=249.67, Return=-44.54%
# 2025-10-08 13:07:35,680 - INFO - YESBANK: Open_t-12=24.40, Close_t-1=21.48, Return=-11.97%
# 2025-10-08 13:07:35,681 - INFO - ZEEL: Open_t-12=160.00, Close_t-1=130.42, Return=-18.49%
# 2025-10-08 13:07:35,684 - INFO - Selected 10 stocks for 2025-06 (Top Return: 31.15%)
# 2025-10-08 13:07:35,694 - INFO - Uninvested cash (will be carried forward): ₹14129.19
# 2025-10-08 13:07:35,705 - INFO - Capital: ₹8,357,249 → ₹8,719,476 (4.33%)
# 2025-10-08 13:07:35,706 - INFO - --------------------------------------------------------------------------------
# 2025-10-08 13:07:35,706 - INFO - Processing 2025-07
# 2025-10-08 13:07:35,719 - INFO - ACC: Open_t-12=2634.75, Close_t-1=1917.20, Return=-27.23%
# 2025-10-08 13:07:35,720 - INFO - ADANIPORTS: Open_t-12=1483.00, Close_t-1=1450.20, Return=-2.21%
# 2025-10-08 13:07:35,721 - INFO - AMBUJACEM: Open_t-12=668.00, Close_t-1=577.45, Return=-13.56%
# 2025-10-08 13:07:35,722 - INFO - ASIANPAINT: Open_t-12=2889.30, Close_t-1=2341.10, Return=-18.97%
# 2025-10-08 13:07:35,723 - INFO - AXISBANK: Open_t-12=1273.00, Close_t-1=1199.20, Return=-5.80%
# 2025-10-08 13:07:35,724 - INFO - BAJAJ-AUTO: Open_t-12=9505.00, Close_t-1=8376.00, Return=-11.88%
# 2025-10-08 13:07:35,727 - INFO - BANKBARODA: Open_t-12=275.25, Close_t-1=248.78, Return=-9.62%
# 2025-10-08 13:07:35,728 - INFO - BHARTIARTL: Open_t-12=1450.00, Close_t-1=2009.60, Return=38.59%
# 2025-10-08 13:07:35,730 - INFO - BHEL: Open_t-12=301.95, Close_t-1=266.30, Return=-11.81%
# 2025-10-08 13:07:35,731 - INFO - BOSCHLTD: Open_t-12=34000.05, Close_t-1=32680.00, Return=-3.88%
# 2025-10-08 13:07:35,733 - INFO - BPCL: Open_t-12=305.70, Close_t-1=331.95, Return=8.59%
# 2025-10-08 13:07:35,735 - INFO - CIPLA: Open_t-12=1484.95, Close_t-1=1505.90, Return=1.41%
# 2025-10-08 13:07:35,736 - INFO - COALINDIA: Open_t-12=473.35, Close_t-1=391.95, Return=-17.20%
# 2025-10-08 13:07:35,737 - INFO - GAIL: Open_t-12=220.25, Close_t-1=190.84, Return=-13.35%
# 2025-10-08 13:07:35,739 - INFO - GRASIM: Open_t-12=2666.20, Close_t-1=2844.50, Return=6.69%
# 2025-10-08 13:07:35,740 - INFO - HCLTECH: Open_t-12=1465.00, Close_t-1=1728.60, Return=17.99%
# 2025-10-08 13:07:35,740 - INFO - HDFCBANK: Open_t-12=1680.00, Close_t-1=2001.50, Return=19.14%
# 2025-10-08 13:07:35,741 - INFO - HEROMOTOCO: Open_t-12=5595.00, Close_t-1=4237.10, Return=-24.27%
# 2025-10-08 13:07:35,744 - INFO - HINDALCO: Open_t-12=699.00, Close_t-1=692.85, Return=-0.88%
# 2025-10-08 13:07:35,745 - INFO - HINDUNILVR: Open_t-12=2461.05, Close_t-1=2294.60, Return=-6.76%
# 2025-10-08 13:07:35,747 - INFO - ICICIBANK: Open_t-12=1199.60, Close_t-1=1445.80, Return=20.52%
# 2025-10-08 13:07:35,749 - INFO - IDEA: Open_t-12=17.79, Close_t-1=7.43, Return=-58.23%
# 2025-10-08 13:07:35,751 - INFO - INDUSINDBK: Open_t-12=1468.95, Close_t-1=872.10, Return=-40.63%
# 2025-10-08 13:07:35,752 - INFO - INFY: Open_t-12=1559.50, Close_t-1=1601.80, Return=2.71%
# 2025-10-08 13:07:35,753 - INFO - ITC: Open_t-12=426.30, Close_t-1=416.45, Return=-2.31%
# 2025-10-08 13:07:35,754 - INFO - KOTAKBANK: Open_t-12=1802.50, Close_t-1=2163.50, Return=20.03%
# 2025-10-08 13:07:35,755 - INFO - LT: Open_t-12=3535.20, Close_t-1=3669.80, Return=3.81%
# 2025-10-08 13:07:35,756 - INFO - LUPIN: Open_t-12=1615.05, Close_t-1=1938.00, Return=20.00%
# 2025-10-08 13:07:35,757 - INFO - M&M: Open_t-12=2841.00, Close_t-1=3183.20, Return=12.05%
# 2025-10-08 13:07:35,757 - INFO - MARUTI: Open_t-12=12045.00, Close_t-1=12400.00, Return=2.95%
# 2025-10-08 13:07:35,759 - INFO - NTPC: Open_t-12=381.75, Close_t-1=334.90, Return=-12.27%
# 2025-10-08 13:07:35,760 - INFO - ONGC: Open_t-12=275.00, Close_t-1=244.21, Return=-11.20%
# 2025-10-08 13:07:35,763 - INFO - PNB: Open_t-12=123.15, Close_t-1=110.50, Return=-10.27%
# 2025-10-08 13:07:35,764 - INFO - POWERGRID: Open_t-12=331.00, Close_t-1=299.90, Return=-9.40%
# 2025-10-08 13:07:35,767 - INFO - RELIANCE: Open_t-12=3125.05, Close_t-1=1500.60, Return=-51.98%
# 2025-10-08 13:07:35,769 - INFO - SBIN: Open_t-12=849.35, Close_t-1=820.35, Return=-3.41%
# 2025-10-08 13:07:35,771 - INFO - SUNPHARMA: Open_t-12=1520.85, Close_t-1=1675.70, Return=10.18%
# 2025-10-08 13:07:35,772 - INFO - TATAMOTORS: Open_t-12=989.75, Close_t-1=688.00, Return=-30.49%
# 2025-10-08 13:07:35,774 - INFO - TATAPOWER: Open_t-12=441.00, Close_t-1=405.45, Return=-8.06%
# 2025-10-08 13:07:35,775 - INFO - TATASTEEL: Open_t-12=174.50, Close_t-1=159.76, Return=-8.45%
# 2025-10-08 13:07:35,849 - INFO - HCLTECH: Open_t-12=1640.05, Close_t-1=1467.90, Return=-10.50%
# 2025-10-08 13:07:35,851 - INFO - HDFCBANK: Open_t-12=1622.90, Close_t-1=2018.20, Return=24.36%
# 2025-10-08 13:07:35,852 - INFO - HEROMOTOCO: Open_t-12=5487.45, Close_t-1=4260.70, Return=-22.36%
# 2025-10-08 13:07:35,854 - INFO - HINDALCO: Open_t-12=680.00, Close_t-1=683.05, Return=0.45%
# 2025-10-08 13:07:35,855 - INFO - HINDUNILVR: Open_t-12=2714.00, Close_t-1=2521.20, Return=-7.10%
# 2025-10-08 13:07:35,856 - INFO - ICICIBANK: Open_t-12=1212.50, Close_t-1=1481.40, Return=22.18%
# 2025-10-08 13:07:35,857 - INFO - IDEA: Open_t-12=16.36, Close_t-1=6.91, Return=-57.76%
# 2025-10-08 13:07:35,857 - INFO - INDUSINDBK: Open_t-12=1432.00, Close_t-1=798.90, Return=-44.21%
# 2025-10-08 13:07:35,858 - INFO - INFY: Open_t-12=1856.10, Close_t-1=1509.00, Return=-18.70%
# 2025-10-08 13:07:35,860 - INFO - ITC: Open_t-12=495.95, Close_t-1=411.95, Return=-16.94%
# 2025-10-08 13:07:35,861 - INFO - KOTAKBANK: Open_t-12=1807.10, Close_t-1=1978.60, Return=9.49%
# 2025-10-08 13:07:35,863 - INFO - LT: Open_t-12=3810.00, Close_t-1=3636.50, Return=-4.55%
# 2025-10-08 13:07:35,866 - INFO - LUPIN: Open_t-12=1911.00, Close_t-1=1929.10, Return=0.95%
# 2025-10-08 13:07:35,867 - INFO - M&M: Open_t-12=2926.50, Close_t-1=3203.10, Return=9.45%
# 2025-10-08 13:07:35,868 - INFO - MARUTI: Open_t-12=13393.00, Close_t-1=12608.00, Return=-5.86%
# 2025-10-08 13:07:35,870 - INFO - NTPC: Open_t-12=419.90, Close_t-1=334.25, Return=-20.40%
# 2025-10-08 13:07:35,871 - INFO - ONGC: Open_t-12=337.80, Close_t-1=241.00, Return=-28.66%
# 2025-10-08 13:07:35,872 - INFO - PNB: Open_t-12=124.50, Close_t-1=105.38, Return=-15.36%
# 2025-10-08 13:07:35,873 - INFO - POWERGRID: Open_t-12=351.15, Close_t-1=291.00, Return=-17.13%
# 2025-10-08 13:07:35,874 - INFO - RELIANCE: Open_t-12=3024.00, Close_t-1=1390.20, Return=-54.03%
# 2025-10-08 13:07:35,874 - INFO - SBIN: Open_t-12=877.80, Close_t-1=796.55, Return=-9.26%
# 2025-10-08 13:07:35,877 - INFO - SUNPHARMA: Open_t-12=1725.50, Close_t-1=1706.70, Return=-1.09%
# 2025-10-08 13:07:35,879 - INFO - TATAMOTORS: Open_t-12=1167.00, Close_t-1=665.95, Return=-42.93%
# 2025-10-08 13:07:35,881 - INFO - TATAPOWER: Open_t-12=454.95, Close_t-1=397.75, Return=-12.57%
# 2025-10-08 13:07:35,883 - INFO - TATASTEEL: Open_t-12=168.20, Close_t-1=157.94, Return=-6.10%
# 2025-10-08 13:07:35,984 - INFO - TCS: Open_t-12=4576.00, Close_t-1=3084.70, Return=-32.59%
# 2025-10-08 13:07:35,985 - INFO - TECHM: Open_t-12=1636.50, Close_t-1=1481.40, Return=-9.48%
# 2025-10-08 13:07:35,986 - INFO - ULTRACEMCO: Open_t-12=11325.00, Close_t-1=12640.00, Return=11.61%
# 2025-10-08 13:07:35,987 - INFO - VEDL: Open_t-12=472.70, Close_t-1=420.65, Return=-11.01%
# 2025-10-08 13:07:35,988 - INFO - WIPRO: Open_t-12=538.40, Close_t-1=249.41, Return=-53.68%
# 2025-10-08 13:07:35,989 - INFO - YESBANK: Open_t-12=23.61, Close_t-1=19.10, Return=-19.10%
# 2025-10-08 13:07:35,990 - INFO - ZEEL: Open_t-12=141.38, Close_t-1=116.04, Return=-17.92%
# 2025-10-08 13:07:35,994 - INFO - Selected 9 stocks for 2025-09 (Top Return: 23.37%)
# 2025-10-08 13:07:36,004 - INFO - Uninvested cash (will be carried forward): ₹51469.31
# 2025-10-08 13:07:36,011 - INFO - Capital: ₹8,039,268 → ₹8,074,257 (0.44%)
# 2025-10-08 13:07:36,016 - INFO -
# Performance Summary:
# 2025-10-08 13:07:36,017 - INFO -   Initial Capital: ₹5,000,000.00
# 2025-10-08 13:07:36,017 - INFO -   Final Capital: ₹8,074,257.01
# 2025-10-08 13:07:36,018 - INFO -   Total Return: 61.49%
# 2025-10-08 13:07:36,019 - INFO -   Annualized Return: 5.80%
# 2025-10-08 13:07:36,019 - INFO -   Sharpe Ratio: 0.41
# 2025-10-08 13:07:36,020 - INFO -   Max Drawdown: -27.13%
# 2025-10-08 13:07:36,020 - INFO -   Win Rate: 51.96%
# 2025-10-08 13:07:36,021 - INFO - ================================================================================
# 2025-10-08 13:07:36,021 - INFO - Backtest Complete
# 2025-10-08 13:07:36,022 - INFO - ================================================================================
# ================================================================================
# BACKTEST RESULTS (12-Month Momentum Strategy)
# ================================================================================

# %%
# Display performance summary
print("\n📊 PERFORMANCE SUMMARY (12-Month Momentum Strategy)")
print("=" * 80)
print(f"Initial Capital:      ₹{metrics['initial_capital']:,.2f}")
print(f"Final Capital:        ₹{metrics['final_capital']:,.2f}")
print(f"Total Return:         {metrics['total_return_pct']:.2f}%")
print(f"Annualized Return:    {metrics['annualized_return_pct']:.2f}%")
print(f"Sharpe Ratio:         {metrics['sharpe_ratio']:.2f}")
print(f"Max Drawdown:         {metrics['max_drawdown_pct']:.2f}%")
print(f"Win Rate:             {metrics['win_rate_pct']:.2f}%")
print("=" * 80)

# Show sample of ledger
print("\n📋 Sample Ledger:")
print(ledger[['month', 'capital_start', 'unallocated_cash', 'net_profit', 'capital_end']].head(10))
# Out:
# 📊 PERFORMANCE SUMMARY (12-Month Momentum Strategy)
# ================================================================================
# Initial Capital:      ₹5,000,000.00
# Final Capital:        ₹8,074,257.01
# Total Return:         61.49%
# Annualized Return:    5.80%
# Sharpe Ratio:         0.41
# Max Drawdown:         -27.13%
# Win Rate:             51.96%
# ================================================================================
#
# 📋 Sample Ledger:
#      month  capital_start  unallocated_cash  net_profit  capital_end
# 0  2017-04     5000000.00           3756.85    92906.95   5092906.95
# 1  2017-05     5092906.95         517792.25  -147179.90   4945727.05
# 2  2017-06     4945727.05           4080.35   -46810.75   4898916.30
# 3  2017-07     4898916.30           7071.05   380722.20   5279638.50
# 4  2017-08     5279638.50           5909.55   -72199.75   5207438.75
# 5  2017-09     5207438.75          10246.10  -350687.15   4856751.60
# 6  2017-10     4856751.60           9009.80   302878.50   5159630.10
# 7  2017-11     5159630.10           7614.35  -288701.90   4870928.20
# 8  2017-12     4870928.20           8787.15   350817.75   5221745.95
# 9  2018-01     5221745.95           3311.85    -6057.80   5215688.15

# %% [markdown]
# ## 7. Detailed Monthly Portfolio Breakdown

# %%
# First, we need to load and compute monthly prices (same as done in backtest)
price_data = data_loader.load_price_data()
monthly_prices = MonthlyPriceComputer.compute_monthly_prices(price_data)

print("Monthly prices computed for detailed breakdown\n")

def create_detailed_portfolio_breakdown(
    ledger: pd.DataFrame, 
    monthly_prices: pd.DataFrame
) -> pd.DataFrame:
    """
    Create detailed breakdown of portfolio holdings for each month.
    Shows: Month, Company, Shares Bought, Buy Price, Sell Price, Return per Stock
    Uses whole shares (floored) to match actual backtest logic.
    """
    detailed_records = []
    
    for idx, row in ledger.iterrows():
        month = pd.Period(row['month'])
        month_data = monthly_prices[monthly_prices['year_month'] == month]
        
        # Get list of tickers for this month
        tickers = row['selected_tickers'].split(', ')
        
        # Calculate shares for each ticker
        capital_per_stock = row['capital_start'] / len(tickers)
        
        # Calculate returns directly from price data instead of parsing string
        for ticker in tickers:
            ticker_month_data = month_data[month_data['ticker'] == ticker]
            
            if len(ticker_month_data) > 0:
                buy_price = ticker_month_data['first_close'].iloc[0]
                sell_price = ticker_month_data['last_close'].iloc[0]
                
                # Use whole shares only (floor) - matches backtest logic
                shares = np.floor(capital_per_stock / buy_price)
                
                # Calculate stock return from actual prices with whole shares
                invested_amount = shares * buy_price
                ending_value = shares * sell_price
                stock_return = (ending_value - invested_amount) / invested_amount if invested_amount > 0 else 0
                profit_loss = ending_value - invested_amount
                
                detailed_records.append({
                    'month': row['month'],
                    'company': ticker,
                    'shares_bought': shares,
                    'buy_price': buy_price,
                    'sell_price': sell_price,
                    'invested_amount': invested_amount,
                    'ending_value': ending_value,
                    'stock_return_pct': stock_return * 100,
                    'profit_loss': profit_loss
                })
    
    detailed_df = pd.DataFrame(detailed_records)
    return detailed_df

# Create the detailed breakdown
detailed_portfolio = create_detailed_portfolio_breakdown(ledger, monthly_prices)

print("Detailed Portfolio Breakdown Created!")
print(f"Total records: {len(detailed_portfolio)} (stocks across {len(ledger)} months)")
print(f"\nColumns: {list(detailed_portfolio.columns)}")
# Out:
# 2025-10-08 13:07:36,063 - INFO - Loading price data from data\combined_nifty50_6month_snapshots.csv
# 2025-10-08 13:07:36,284 - INFO - Loaded 109977 price records for 50 tickers from 2016-04-01 00:00:00 to 2025-09-26 00:00:00
# 2025-10-08 13:07:36,287 - INFO - Computing monthly first-close and last-close prices
# 2025-10-08 13:07:36,336 - INFO - Computed monthly prices for 5302 month-ticker pairs
# Monthly prices computed for detailed breakdown
#
# Detailed Portfolio Breakdown Created!
# Total records: 1002 (stocks across 102 months)
#
# Columns: ['month', 'company', 'shares_bought', 'buy_price', 'sell_price', 'invested_amount', 'ending_value', 'stock_return_pct', 'profit_loss']

# %%
# Display sample of detailed portfolio for first month
print("=" * 100)
print("SAMPLE: APRIL 2017 PORTFOLIO")
print("=" * 100)
april_2017 = detailed_portfolio[detailed_portfolio['month'] == '2017-04'].copy()
april_2017_display = april_2017[['company', 'shares_bought', 'buy_price', 'sell_price', 'invested_amount', 'stock_return_pct', 'profit_loss']].copy()

# Format for better display
april_2017_display['shares_bought'] = april_2017_display['shares_bought'].apply(lambda x: f"{x:.2f}")
april_2017_display['buy_price'] = april_2017_display['buy_price'].apply(lambda x: f"₹{x:.2f}")
april_2017_display['sell_price'] = april_2017_display['sell_price'].apply(lambda x: f"₹{x:.2f}")
april_2017_display['invested_amount'] = april_2017_display['invested_amount'].apply(lambda x: f"₹{x:,.0f}")
april_2017_display['stock_return_pct'] = april_2017_display['stock_return_pct'].apply(lambda x: f"{x:.2f}%")
april_2017_display['profit_loss'] = april_2017_display['profit_loss'].apply(lambda x: f"₹{x:,.0f}")

print(april_2017_display.to_string(index=False))
print("=" * 100)
# Out:
# ====================================================================================================
# SAMPLE: APRIL 2017 PORTFOLIO
# ====================================================================================================
#    company shares_bought buy_price sell_price invested_amount stock_return_pct profit_loss
#       VEDL       1833.00   ₹272.70    ₹243.55        ₹499,859          -10.69%    ₹-53,432
#   HINDALCO       2582.00   ₹193.60    ₹199.35        ₹499,875            2.97%     ₹14,846
#      CAIRN       1639.00   ₹305.05    ₹285.35        ₹499,977           -6.46%    ₹-32,288
#        PNB       3334.00   ₹149.95    ₹168.85        ₹499,933           12.60%     ₹63,013
#     MARUTI         82.00  ₹6072.00   ₹6524.85        ₹497,904            7.46%     ₹37,134
#       SBIN       1705.00   ₹293.15    ₹289.75        ₹499,821           -1.16%     ₹-5,797
# INDUSINDBK        356.00  ₹1403.45   ₹1444.95        ₹499,628            2.96%     ₹14,774
#       BHEL       2994.00   ₹166.95    ₹175.70        ₹499,848            5.24%     ₹26,197
#  POWERGRID       2548.00   ₹196.20    ₹208.00        ₹499,918            6.01%     ₹30,066
#       ZEEL        945.00   ₹528.55    ₹526.85        ₹499,480           -0.32%     ₹-1,606
# ====================================================================================================

# %%
# Function to view any month's detailed portfolio
def view_month_portfolio(month_str: str):
    """
    Display detailed portfolio breakdown for a specific month.
    
    Args:
        month_str: Month in format 'YYYY-MM' (e.g., '2017-04', '2019-10')
    """
    month_data = detailed_portfolio[detailed_portfolio['month'] == month_str].copy()
    
    if len(month_data) == 0:
        print(f"No data found for month: {month_str}")
        return None
    
    print("=" * 120)
    print(f"PORTFOLIO BREAKDOWN: {month_str}")
    print("=" * 120)
    
    # Calculate monthly summary
    total_invested = month_data['invested_amount'].sum()
    total_ending = month_data['ending_value'].sum()
    total_profit = month_data['profit_loss'].sum()
    portfolio_return = (total_profit / total_invested) * 100
    
    print(f"Total Invested: ₹{total_invested:,.0f}")
    print(f"Total Ending Value: ₹{total_ending:,.0f}")
    print(f"Total Profit/Loss: ₹{total_profit:,.0f}")
    print(f"Portfolio Return: {portfolio_return:.2f}%")
    print("=" * 120)
    
    # Display individual stocks
    display_df = month_data[['company', 'shares_bought', 'buy_price', 'sell_price', 
                              'invested_amount', 'ending_value', 'stock_return_pct', 'profit_loss']].copy()
    
    # Sort by return (best to worst)
    display_df = display_df.sort_values('stock_return_pct', ascending=False)
    
    print(f"\n{'Company':<12} {'Shares':<12} {'Buy Price':<12} {'Sell Price':<12} {'Invested':<15} {'End Value':<15} {'Return':<10} {'Profit/Loss':<12}")
    print("-" * 120)
    
    for _, row in display_df.iterrows():
        print(f"{row['company']:<12} {row['shares_bought']:<12.2f} ₹{row['buy_price']:<11.2f} ₹{row['sell_price']:<11.2f} "
              f"₹{row['invested_amount']:<14,.0f} ₹{row['ending_value']:<14,.0f} {row['stock_return_pct']:<9.2f}% ₹{row['profit_loss']:<11,.0f}")
    
    print("=" * 120)
    return display_df

# Example: View April 2017 portfolio
view_month_portfolio('2017-04')
# Out:
# ========================================================================================================================
# PORTFOLIO BREAKDOWN: 2017-04
# ========================================================================================================================
# Total Invested: ₹4,996,243
# Total Ending Value: ₹5,089,150
# Total Profit/Loss: ₹92,907
# Portfolio Return: 1.86%
# ========================================================================================================================
#
# Company      Shares       Buy Price    Sell Price   Invested        End Value       Return     Profit/Loss
# ------------------------------------------------------------------------------------------------------------------------
# PNB          3334.00      ₹149.95      ₹168.85      ₹499,933        ₹562,946        12.60    % ₹63,013
# MARUTI       82.00        ₹6072.00     ₹6524.85     ₹497,904        ₹535,038        7.46     % ₹37,134
# POWERGRID    2548.00      ₹196.20      ₹208.00      ₹499,918        ₹529,984        6.01     % ₹30,066
# BHEL         2994.00      ₹166.95      ₹175.70      ₹499,848        ₹526,046        5.24     % ₹26,197
# HINDALCO     2582.00      ₹193.60      ₹199.35      ₹499,875        ₹514,722        2.97     % ₹14,846
# INDUSINDBK   356.00       ₹1403.45     ₹1444.95     ₹499,628        ₹514,402        2.96     % ₹14,774
# ZEEL         945.00       ₹528.55      ₹526.85      ₹499,480        ₹497,873        -0.32    % ₹-1,606
# SBIN         1705.00      ₹293.15      ₹289.75      ₹499,821        ₹494,024        -1.16    % ₹-5,797
# CAIRN        1639.00      ₹305.05      ₹285.35      ₹499,977        ₹467,689        -6.46    % ₹-32,288
# VEDL         1833.00      ₹272.70      ₹243.55      ₹499,859        ₹446,427        -10.69   % ₹-53,432
# ========================================================================================================================
#       company  shares_bought  buy_price  sell_price  invested_amount  \
# 3         PNB         3334.0     149.95      168.85        499933.30
# 4      MARUTI           82.0    6072.00     6524.85        497904.00
# 8   POWERGRID         2548.0     196.20      208.00        499917.60
# 7        BHEL         2994.0     166.95      175.70        499848.30
# 1    HINDALCO         2582.0     193.60      199.35        499875.20
# 6  INDUSINDBK          356.0    1403.45     1444.95        499628.20
# 9        ZEEL          945.0     528.55      526.85        499479.75
# 5        SBIN         1705.0     293.15      289.75        499820.75
# 2       CAIRN         1639.0     305.05      285.35        499976.95
# 0        VEDL         1833.0     272.70      243.55        499859.10
#
#    ending_value  stock_return_pct  profit_loss
# 3     562945.90         12.604201     63012.60
# 4     535037.70          7.458004     37133.70
# 8     529984.00          6.014271     30066.40
# 7     526045.80          5.241090     26197.50
# 1     514721.70          2.970041     14846.50
# 6     514402.20          2.956999     14774.00
# 9     497873.25         -0.321635     -1606.50
# 5     494023.75         -1.159816     -5797.00
# 2     467688.65         -6.457958    -32288.30
# 0     446427.15        -10.689402    -53431.95

# %%
# View October 2019 portfolio (as requested in question)
view_month_portfolio('2019-10')
# Out:
# ========================================================================================================================
# PORTFOLIO BREAKDOWN: 2019-10
# ========================================================================================================================
# Total Invested: ₹4,754,706
# Total Ending Value: ₹4,984,754
# Total Profit/Loss: ₹230,047
# Portfolio Return: 4.84%
# ========================================================================================================================
#
# Company      Shares       Buy Price    Sell Price   Invested        End Value       Return     Profit/Loss
# ------------------------------------------------------------------------------------------------------------------------
# BAJAJ-AUTO   163.00       ₹2910.00     ₹3247.35     ₹474,330        ₹529,318        11.59    % ₹54,988
# HINDUNILVR   239.00       ₹1990.30     ₹2175.35     ₹475,682        ₹519,909        9.30     % ₹44,227
# ICICIBANK    1121.00      ₹424.60      ₹463.05      ₹475,977        ₹519,079        9.06     % ₹43,102
# AXISBANK     701.00       ₹679.15      ₹736.35      ₹476,084        ₹516,181        8.42     % ₹40,097
# HDFC         238.00       ₹1995.65     ₹2131.90     ₹474,965        ₹507,392        6.83     % ₹32,428
# BPCL         964.00       ₹493.90      ₹526.60      ₹476,120        ₹507,642        6.62     % ₹31,523
# ASIANPAINT   269.00       ₹1766.10     ₹1809.60     ₹475,081        ₹486,782        2.46     % ₹11,702
# LT           325.00       ₹1464.05     ₹1473.05     ₹475,816        ₹478,741        0.61     % ₹2,925
# ADANIPORTS   1178.00      ₹404.05      ₹395.80      ₹475,971        ₹466,252        -2.04    % ₹-9,718
# KOTAKBANK    288.00       ₹1648.20     ₹1574.50     ₹474,682        ₹453,456        -4.47    % ₹-21,226
# ========================================================================================================================
#         company  shares_bought  buy_price  sell_price  invested_amount  \
# 308  BAJAJ-AUTO          163.0    2910.00     3247.35        474330.00
# 304  HINDUNILVR          239.0    1990.30     2175.35        475681.70
# 300   ICICIBANK         1121.0     424.60      463.05        475976.60
# 307    AXISBANK          701.0     679.15      736.35        476084.15
# 306        HDFC          238.0    1995.65     2131.90        474964.70
# 302        BPCL          964.0     493.90      526.60        476119.60
# 301  ASIANPAINT          269.0    1766.10     1809.60        475080.90
# 305          LT          325.0    1464.05     1473.05        475816.25
# 303  ADANIPORTS         1178.0     404.05      395.80        475970.90
# 299   KOTAKBANK          288.0    1648.20     1574.50        474681.60
#
#      ending_value  stock_return_pct  profit_loss
# 308     529318.05         11.592784     54988.05
# 304     519908.65          9.297593     44226.95
# 300     519079.05          9.055582     43102.45
# 307     516181.35          8.422293     40097.20
# 306     507392.20          6.827349     32427.50
# 302     507642.40          6.620773     31522.80
# 301     486782.40          2.463054     11701.50
# 305     478741.25          0.614733      2925.00
# 303     466252.40         -2.041827     -9718.50
# 299     453456.00         -4.471545    -21225.60

# %%
# View multiple months at once
print("\n\n")
print("VIEWING MULTIPLE MONTHS:")
print("\n")

# View some interesting months
for month in ['2017-04', '2018-06', '2020-03', '2021-12', '2024-09']:
    view_month_portfolio(month)
    print("\n")
# Out:
# VIEWING MULTIPLE MONTHS:
#
#
# ========================================================================================================================
# PORTFOLIO BREAKDOWN: 

# ========================================================================================================================
#
# Company      Shares       Buy Price    Sell Price   Invested        End Value       Return     Profit/Loss
# ------------------------------------------------------------------------------------------------------------------------
# HINDUNILVR   230.00       ₹2159.45     ₹2298.50     ₹496,673        ₹528,655        6.44     % ₹31,982
# ASIANPAINT   278.00       ₹1786.80     ₹1666.50     ₹496,730        ₹463,287        -6.73    % ₹-33,443
# BHARTIARTL   960.00       ₹518.35      ₹440.90      ₹497,616        ₹423,264        -14.94   % ₹-74,352
# RELIANCE     378.00       ₹1316.15     ₹1113.75     ₹497,505        ₹420,998        -15.38   % ₹-76,507
# KOTAKBANK    311.00       ₹1599.00     ₹1296.05     ₹497,289        ₹403,072        -18.95   % ₹-94,217
# ULTRACEMCO   120.00       ₹4141.70     ₹3244.85     ₹497,004        ₹389,382        -21.65   % ₹-107,622
# BPCL         1207.00      ₹412.35      ₹316.90      ₹497,706        ₹382,498        -23.15   % ₹-115,208
# HDFC         228.00       ₹2179.65     ₹1633.10     ₹496,960        ₹372,347        -25.08   % ₹-124,613
# SBIN         1732.00      ₹287.40      ₹196.85      ₹497,777        ₹340,944        -31.51   % ₹-156,833
# ICICIBANK    984.00       ₹506.10      ₹323.75      ₹498,002        ₹318,570        -36.03   % ₹-179,432
# ========================================================================================================================
#
#
# ========================================================================================================================
# PORTFOLIO BREAKDOWN: 2021-12
# ========================================================================================================================
# Total Invested: ₹6,453,970
# Total Ending Value: ₹6,628,166
# Total Profit/Loss: ₹174,196
# Portfolio Return: 2.70%
# ========================================================================================================================
#
# Company      Shares       Buy Price    Sell Price   Invested        End Value       Return     Profit/Loss
# ------------------------------------------------------------------------------------------------------------------------
# TECHM        406.00       ₹1587.60     ₹1790.55     ₹644,566        ₹726,963        12.78    % ₹82,398
# WIPRO        1017.00      ₹634.80      ₹715.35      ₹645,592        ₹727,511        12.69    % ₹81,919
# HINDALCO     1519.00      ₹424.90      ₹475.55      ₹645,423        ₹722,360        11.92    % ₹76,937
# TATAMOTORS   1358.00      ₹475.25      ₹482.40      ₹645,390        ₹655,099        1.50     % ₹9,710
# ONGC         4539.00      ₹142.25      ₹142.40      ₹645,673        ₹646,354        0.11     % ₹681
# VEDL         1859.00      ₹347.25      ₹341.20      ₹645,538        ₹634,291        -1.74    % ₹-11,247
# BHEL         10753.00     ₹60.05       ₹58.95       ₹645,718        ₹633,889        -1.83    % ₹-11,828
# TATAPOWER    2867.00      ₹225.20      ₹220.95      ₹645,648        ₹633,464        -1.89    % ₹-12,185
# SBIN         1358.00      ₹475.30      ₹460.45      ₹645,457        ₹625,291        -3.12    % ₹-20,166
# GRASIM       384.00       ₹1679.60     ₹1622.25     ₹644,966        ₹622,944        -3.41    % ₹-22,022
# ========================================================================================================================
#
#
# ========================================================================================================================
# PORTFOLIO BREAKDOWN: 2024-09
# ========================================================================================================================
# Total Invested: ₹10,261,487
# Total Ending Value: ₹10,496,426
# Total Profit/Loss: ₹234,939
# Portfolio Return: 2.29%
# ========================================================================================================================
#
# Company      Shares       Buy Price    Sell Price   Invested        End Value       Return     Profit/Loss
# ------------------------------------------------------------------------------------------------------------------------
# BAJAJ-AUTO   92.00        ₹11126.10    ₹12345.95    ₹1,023,601      ₹1,135,827      10.96    % ₹112,226
# VEDL         2216.00      ₹463.25      ₹512.65      ₹1,026,562      ₹1,136,032      10.66    % ₹109,470
# BHARTIARTL   653.00       ₹1571.35     ₹1709.55     ₹1,026,092      ₹1,116,336      8.79     % ₹90,245
# NTPC         2504.00      ₹410.00      ₹443.20      ₹1,026,640      ₹1,109,773      8.10     % ₹83,133
# GAIL         4387.00      ₹234.06      ₹240.29      ₹1,026,821      ₹1,054,152      2.66     % ₹27,331
# LUPIN        459.00       ₹2232.75     ₹2191.10     ₹1,024,832      ₹1,005,715      -1.87    % ₹-19,117
# COALINDIA    1971.00      ₹520.85      ₹510.15      ₹1,026,595      ₹1,005,506      -2.05    % ₹-21,090
# BHEL         3580.00      ₹286.80      ₹279.70      ₹1,026,744      ₹1,001,326      -2.48    % ₹-25,418
# ADANIPORTS   687.00       ₹1494.50     ₹1448.20     ₹1,026,722      ₹994,913        -3.10    % ₹-31,808
# ONGC         3148.00      ₹326.20      ₹297.60      ₹1,026,878      ₹936,845        -8.77    % ₹-90,033
# ========================================================================================================================

# %%
# Save the detailed portfolio breakdown to CSV for further analysis
output_dir = Path("results")
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
detailed_file = output_dir / f"detailed_portfolio_breakdown_{timestamp}.csv"

detailed_portfolio.to_csv(detailed_file, index=False)
print(f"✓ Saved detailed portfolio breakdown to: {detailed_file}")
print(f"  Total records: {len(detailed_portfolio)}")
print(f"  Columns: {', '.join(detailed_portfolio.columns)}")
print(f"\nYou can now analyze:")
print(f"  - Which stocks were bought each month")
print(f"  - How many shares of each stock")
print(f"  - Buy/sell prices for each position")
print(f"  - Returns generated by each stock in each month")
print(f"  - Profit/loss contribution by stock")
# Out:
# ✓ Saved detailed portfolio breakdown to: results\detailed_portfolio_breakdown_20251008_130737.csv
#   Total records: 1002
#   Columns: month, company, shares_bought, buy_price, sell_price, invested_amount, ending_value, stock_return_pct, profit_loss
#
# You can now analyze:
#   - Which stocks were bought each month
#   - How many shares of each stock
#   - Buy/sell prices for each position
#   - Returns generated by each stock in each month
#   - Profit/loss contribution by stock

# %% [markdown]
# ## 8. Results Analysis

# %%
# Display performance metrics
print("=" * 80)
print("PERFORMANCE METRICS")
print("=" * 80)
print(f"Initial Capital:      ₹{metrics['initial_capital']:,.2f}")
print(f"Final Capital:        ₹{metrics['final_capital']:,.2f}")
print(f"Total Return:         {metrics['total_return_pct']:.2f}%")
print(f"Annualized Return:    {metrics['annualized_return_pct']:.2f}%")
print(f"Avg Monthly Return:   {metrics['avg_monthly_return_pct']:.2f}%")
print(f"Monthly Volatility:   {metrics['monthly_volatility_pct']:.2f}%")
print(f"Sharpe Ratio:         {metrics['sharpe_ratio']:.2f}")
print(f"Max Drawdown:         {metrics['max_drawdown_pct']:.2f}%")
print(f"Win Rate:             {metrics['win_rate_pct']:.2f}%")
print(f"Number of Months:     {metrics['num_months']}")
print(f"Years:                {metrics['num_years']:.2f}")
print("=" * 80)
# Out:
# ================================================================================
# PERFORMANCE METRICS
# ================================================================================
# Initial Capital:      ₹5,000,000.00
# Final Capital:        ₹8,074,257.01
# Total Return:         61.49%
# Annualized Return:    5.80%
# Avg Monthly Return:   0.61%
# Monthly Volatility:   5.18%
# Sharpe Ratio:         0.41
# Max Drawdown:         -27.13%
# Win Rate:             51.96%
# Number of Months:     102
# Years:                8.50
# ================================================================================

# %%
# View first few months
print("\nFirst 10 Months:")
ledger.head(10)
# Out:
# First 10 Months:
#      month  capital_start  capital_end  net_profit  gross_profit  total_costs  \
# 0  2017-04     5000000.00   5092906.95    92906.95      92906.95          0.0
# 1  2017-05     5092906.95   4945727.05  -147179.90    -147179.90          0.0
# 2  2017-06     4945727.05   4898916.30   -46810.75     -46810.75          0.0
# 3  2017-07     4898916.30   5279638.50   380722.20     380722.20          0.0
# 4  2017-08     5279638.50   5207438.75   -72199.75     -72199.75          0.0
# 5  2017-09     5207438.75   4856751.60  -350687.15    -350687.15          0.0
# 6  2017-10     4856751.60   5159630.10   302878.50     302878.50          0.0
# 7  2017-11     5159630.10   4870928.20  -288701.90    -288701.90          0.0
# 8  2017-12     4870928.20   5221745.95   350817.75     350817.75          0.0
# 9  2018-01     5221745.95   5215688.15    -6057.80      -6057.80          0.0
#
#    taxes  unallocated_cash  portfolio_roi  \
# 0    0.0           3756.85       0.018581
# 1    0.0         517792.25      -0.028899
# 2    0.0           4080.35      -0.009465
# 3    0.0           7071.05       0.077716
# 4    0.0           5909.55      -0.013675
# 5    0.0          10246.10      -0.067343
# 6    0.0           9009.80       0.062362
# 7    0.0           7614.35      -0.055954
# 8    0.0           8787.15       0.072023
# 9    0.0           3311.85      -0.001160
#
#                                     selected_tickers  num_stocks  \
# 0  VEDL, HINDALCO, CAIRN, PNB, MARUTI, SBIN, INDU...          10
# 1  VEDL, HINDALCO, CAIRN, PNB, MARUTI, SBIN, POWE...           9
# 2  VEDL, HINDALCO, PNB, ADANIPORTS, MARUTI, SBIN,...          10
# 3  VEDL, ADANIPORTS, MARUTI, HINDALCO, RELIANCE, ...          10
# 4  VEDL, ADANIPORTS, HINDALCO, MARUTI, RELIANCE, ...          10
# 5  VEDL, MARUTI, RELIANCE, HINDALCO, ADANIPORTS, ...          10
# 6  VEDL, HINDALCO, ADANIPORTS, MARUTI, INDUSINDBK...          10
# 7  HINDALCO, VEDL, BHARTIARTL, HINDUNILVR, ADANIP...          10
# 8  MARUTI, INDUSINDBK, BHARTIARTL, HINDUNILVR, AD...          10
# 9  MARUTI, HINDALCO, BHARTIARTL, HINDUNILVR, VEDL...          10
#
#                                   per_ticker_returns  cumulative_return  \
# 0  {'VEDL': np.float64(-0.1068940227356068), 'HIN...           0.018581
# 1  {'VEDL': np.float64(-0.013231341740748397), 'H...          -0.010855
# 2  {'VEDL': np.float64(0.07697297297297302), 'HIN...          -0.020217
# 3  {'VEDL': np.float64(0.10047188360204491), 'ADA...           0.055928
# 4  {'VEDL': np.float64(0.0951958872540327), 'ADAN...           0.041488
# 5  {'VEDL': np.float64(-0.0022225750119066073), '...          -0.028650
# 6  {'VEDL': np.float64(0.042733699921445475), 'HI...           0.031926
# 7  {'HINDALCO': np.float64(-0.12658917544496917),...          -0.025814
# 8  {'MARUTI': np.float64(0.13016029736322438), 'I...           0.044349
# 9  {'MARUTI': np.float64(-0.014732850526839142), ...           0.043138
#
#    cumulative_return_pct
# 0               1.858139
# 1              -1.085459
# 2              -2.021674
# 3               5.592770
# 4               4.148775
# 5              -2.864968
# 6               3.192602
# 7              -2.581436
# 8               4.434919
# 9               4.313763

# %%
# View last few months
print("\nLast 10 Months:")
ledger.tail(10)
# Out:
# Last 10 Months:
#        month  capital_start  capital_end  net_profit  gross_profit  \
# 92   2024-12     8970026.71   8793307.74  -176718.97    -176718.97
# 93   2025-01     8793307.74   8357037.84  -436269.90    -436269.90
# 94   2025-02     8357037.84   7654815.54  -702222.30    -702222.30
# 95   2025-03     7654815.54   8117063.44   462247.90     462247.90
# 96   2025-04     8117063.44   8432615.29   315551.85     315551.85
# 97   2025-05     8432615.29   8357249.09   -75366.20     -75366.20
# 98   2025-06     8357249.09   8719475.69   362226.60     362226.60
# 99   2025-07     8719475.69   8396717.34  -322758.35    -322758.35
# 100  2025-08     8396717.34   8039268.24  -357449.10    -357449.10
# 101  2025-09     8039268.24   8074257.01    34988.77      34988.77
#
#      total_costs  taxes  unallocated_cash  portfolio_roi  \
# 92           0.0    0.0          30461.78      -0.019701
# 93           0.0    0.0          39687.09      -0.049614
# 94           0.0    0.0          20916.89      -0.084028
# 95           0.0    0.0           8785.84       0.060387
# 96           0.0    0.0          12261.29       0.038875
# 97           0.0    0.0          15038.19      -0.008937
# 98           0.0    0.0          14129.19       0.043343
# 99           0.0    0.0           9621.44      -0.037016
# 100          0.0    0.0          44450.34      -0.042570
# 101          0.0    0.0          51469.31       0.004352
#
#                                       selected_tickers  num_stocks  \
# 92   VEDL, M&M, BOSCHLTD, LUPIN, BHARTIARTL, POWERG...          10
# 93   LUPIN, M&M, VEDL, BHARTIARTL, BOSCHLTD, SUNPHA...          10
# 94   M&M, VEDL, BHARTIARTL, LUPIN, TECHM, SUNPHARMA...          10
# 95   VEDL, BHARTIARTL, M&M, HINDALCO, HDFCBANK, LUP...          10
# 96   VEDL, BHARTIARTL, M&M, HDFCBANK, ICICIBANK, LU...          10
# 97   BHARTIARTL, KOTAKBANK, M&M, LUPIN, HDFCBANK, I...          10
# 98   BHARTIARTL, TECHM, ICICIBANK, HDFCBANK, LUPIN,...          10
# 99   BHARTIARTL, ICICIBANK, KOTAKBANK, LUPIN, HDFCB...          10
# 100  BHARTIARTL, HDFCBANK, ICICIBANK, BOSCHLTD, KOT...          10
# 101  BOSCHLTD, MARUTI, BHARTIARTL, ICICIBANK, M&M, ...           9
#
#                                     per_ticker_returns  cumulative_return  \
# 92   {'VEDL': np.float64(-0.034958202149603684), 'M...           0.758662
# 93   {'LUPIN': np.float64(-0.12027992726965207), 'M...           0.671408
# 94   {'M&M': np.float64(-0.15979523848216465), 'VED...           0.530963
# 95   {'VEDL': np.float64(0.13259195893926431), 'BHA...           0.623413
# 96   {'VEDL': np.float64(-0.08351552251858335), 'BH...           0.686523
# 97   {'BHARTIARTL': np.float64(0.002321939629569631...           0.671450
# 98   {'BHARTIARTL': np.float64(0.08386818402459414)...           0.743895
# 99   {'BHARTIARTL': np.float64(-0.05204516192928603...           0.679343
# 100  {'BHARTIARTL': np.float64(0.002334960730205901...           0.607854
# 101  {'BOSCHLTD': np.float64(-0.06460708593845776),...           0.614851
#
#      cumulative_return_pct
# 92               75.866155
# 93               67.140757
# 94               53.096311
# 95               62.341269
# 96               68.652306
# 97               67.144982
# 98               74.389514
# 99               67.934347
# 100              60.785365
# 101              61.485140

# %% [markdown]
# ## 9. Visualizations

# %%
# Plot 1: Capital Growth Over Time
fig, ax = plt.subplots(figsize=(14, 6))
ledger['month_date'] = pd.to_datetime(ledger['month'])
ax.plot(ledger['month_date'], ledger['capital_end'] / 1_000_000, linewidth=2, color='#00ff00')
ax.axhline(y=INITIAL_CAPITAL / 1_000_000, color='white', linestyle='--', alpha=0.5, label='Initial Capital')
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Capital (Millions ₹)', fontsize=12)
ax.set_title('Portfolio Capital Growth Over Time', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.2)
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Plot 2: Monthly Returns
fig, ax = plt.subplots(figsize=(14, 6))
colors = ['#00ff00' if x > 0 else '#ff0000' for x in ledger['portfolio_roi']]
ax.bar(ledger['month_date'], ledger['portfolio_roi'] * 100, color=colors, alpha=0.7)
ax.axhline(y=0, color='white', linestyle='-', linewidth=0.5)
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Monthly Return (%)', fontsize=12)
ax.set_title('Monthly Portfolio Returns', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.2, axis='y')
plt.tight_layout()
plt.show()

# %%
# Plot 3: Drawdown Chart
fig, ax = plt.subplots(figsize=(14, 6))
cumulative = (1 + ledger['portfolio_roi']).cumprod()
running_max = cumulative.expanding().max()
drawdown = (cumulative - running_max) / running_max * 100
ax.fill_between(ledger['month_date'], drawdown, 0, color='#ff0000', alpha=0.4)
ax.plot(ledger['month_date'], drawdown, color='#ff0000', linewidth=1.5)
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Drawdown (%)', fontsize=12)
ax.set_title(f'Portfolio Drawdown (Max: {metrics["max_drawdown_pct"]:.2f}%)', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.2)
plt.tight_layout()
plt.show()

# %%
# Plot 4: Rolling Sharpe Ratio (12-month window)
fig, ax = plt.subplots(figsize=(14, 6))
rolling_sharpe = ledger['portfolio_roi'].rolling(window=12).mean() / ledger['portfolio_roi'].rolling(window=12).std() * np.sqrt(12)
ax.plot(ledger['month_date'], rolling_sharpe, linewidth=2, color='#00ffff')
ax.axhline(y=metrics['sharpe_ratio'], color='white', linestyle='--', alpha=0.5, label=f'Overall Sharpe: {metrics["sharpe_ratio"]:.2f}')
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Rolling Sharpe Ratio', fontsize=12)
ax.set_title('12-Month Rolling Sharpe Ratio', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.2)
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Plot 5: Distribution of Monthly Returns
fig, ax = plt.subplots(figsize=(14, 6))
ax.hist(ledger['portfolio_roi'] * 100, bins=30, color='#00ffff', alpha=0.7, edgecolor='white')
ax.axvline(x=metrics['avg_monthly_return_pct'], color='#00ff00', linestyle='--', linewidth=2, label=f'Mean: {metrics["avg_monthly_return_pct"]:.2f}%')
ax.axvline(x=0, color='white', linestyle='-', linewidth=0.5)
ax.set_xlabel('Monthly Return (%)', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title('Distribution of Monthly Returns', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.2, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Save Results

# %%
# Save results to CSV
output_dir = Path("results")
output_dir.mkdir(exist_ok=True)

# Create descriptive filename with strategy parameters
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
strategy_name = f"ROI_momentum_{N_STOCKS}stocks"
ledger_file = output_dir / f"{strategy_name}_ledger_{timestamp}.csv"
metrics_file = output_dir / f"{strategy_name}_metrics_{timestamp}.csv"

ledger.to_csv(ledger_file, index=False)
pd.DataFrame([metrics]).to_csv(metrics_file, index=False)

print(f"✓ Saved ledger to: {ledger_file}")
print(f"✓ Saved metrics to: {metrics_file}")
# Out:
# ✓ Saved ledger to: results\ROI_momentum_10stocks_ledger_20251008_130738.csv
# ✓ Saved metrics to: results\ROI_momentum_10stocks_metrics_20251008_130738.csv

# %% [markdown]
# ## 11. Strategy Summary
#
# **12-Month Momentum Strategy**
#
# **Selection Criteria:**
# - **12-Month Momentum Formula:** `(Close_t-1 - Open_t-12) / Open_t-12`
# - Uses previous month's **closing price** vs 12 months ago's **opening price**
# - Lookback: Exactly 12 months (t-12 to t-1)
# - Only stocks with positive returns are selected (stocks that went up over 12 months)
# - Top 10 stocks by return each month
#
# **Execution:**
# - Start Date: April 2017 (with data from April 2016)
# - Initial Capital: ₹50,00,000 (50 lakh)
# - Allocation: Equal weight - ₹5,00,000 per stock
# - Entry: **Close price on first trading day of month**
# - Exit: **Close price on last trading day of month**
# - Rebalancing: Monthly with full profit reinvestment
# - End Date: September 2025
#
# **Capital Flow:**
# - Month start → Select top 10 stocks with highest 12-month momentum (stocks that went up over 12 months)
# - Divide capital equally across selected stocks
# - Buy shares at first day's close price (store fractional rupees in reserve)
# - Hold through entire month
# - Sell at last day's close price
# - Reinvest all profits into next month's capital
# - Repeat until end of data
#
# **Why This Formula?**
# - Classic momentum strategy: buys stocks that went up over the past year
# - Assumes long-term trend continuation - winners keep winning
# - 12-month lookback is the standard momentum period in academic research
# - Logs all calculations for transparency
#
# You can easily modify parameters and re-run the backtest:

# %%
# Example: Run with different number of stocks
def run_backtest_with_params(n_stocks=10, initial_capital=5_000_000):
    """Quick function to run backtest with different parameters."""
    data_loader = DataLoader(data_file="data/combined_nifty50_6month_snapshots.csv")
    selector = MomentumSelector(n_stocks=n_stocks)
    
    engine = BacktestEngine(
        data_loader=data_loader,
        selector=selector,
        initial_capital=initial_capital,
        transaction_cost_per_trade=0.0,
        slippage=0.0,
        tax_rate=0.0
    )
    
    ledger, metrics = engine.run_backtest()
    return ledger, metrics

# Uncomment to try different parameters:
# ledger_5, metrics_5 = run_backtest_with_params(n_stocks=5)
# ledger_15, metrics_15 = run_backtest_with_params(n_stocks=15)
# ledger_20, metrics_20 = run_backtest_with_params(n_stocks=20)
